# %%
# %matplotlib inline
# %load_ext cython
# Out:
# /usr/local/lib/python3.5/site-packages/Cython/Distutils/old_build_ext.py:30: UserWarning: Cython.Distutils.old_build_ext does not properly handle dependencies and is deprecated.
#   "Cython.Distutils.old_build_ext does not properly handle dependencies "

# %%
from pandas import DataFrame, read_sas, read_csv
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import numpy as np

from SECEdgar.crawler import SecCrawler

from bs4 import BeautifulSoup as bs

import time
from datetime import datetime as dt
from datetime import date, timedelta

from collections import defaultdict

import os
import re
import lxml
import redis
import string
import pickle
import math
import zlib

import nltk
from nltk.corpus import stopwords

try: stopwords.words('english')
except LookupError: nltk.download('stopwords')
    
import statsmodels.api as sm
    
rds = redis.Redis()

# %%
# Read in SAS data set - takes a while so try to use redis...
try: data
except NameError:
    if rds.exists('data:word-power'):
        # %time data = pickle.loads(zlib.decompress(rds.get('data:word-power')))
    else:
        # %time data = read_sas("data/crsp_comp.sas7bdat")

        # Trim the SAS data set
        data = data[['CUSIP','PERMNO','cik','date','PRC','RET','vwretd']]

        # Sort the set by cusip, permno, cik, and then year (descending)
        data.sort_values(['CUSIP', 'PERMNO', 'cik', 'date'], ascending=[True, True, True, False], inplace=True)

        # Re-index the dataframe for better access
        data.reset_index(inplace=True)

        rds.set('data:word-power', zlib.compress(pickle.dumps(data)))

# We only need certain columns from the data set and we must set the right index for performance
try: df
except:
    df = data[["cik", "date", "PRC", "RET", "vwretd"]]
    df.set_index(keys=['cik','date'], inplace=True)
    
# Positive words
try: pos_dict, pos_roots, pos_roots_map
except:
    if rds.exists('data:pos-dict') and rds.exists('data:pos-roots') and rds.exists('data:pos-roots-map'):
        pos_dict = pickle.loads(zlib.decompress(rds.get('data:pos-dict')))
        pos_roots = pickle.loads(zlib.decompress(rds.get('data:pos-roots')))
        pos_roots_map = pickle.loads(zlib.decompress(rds.get('data:pos-roots-map')))
    else:
        # Read in the positive word list(s)
        pos_dict = read_csv("data/pos_list.csv", header=None, names=['word'])
        pos_dict = set(pos_dict['word'])
        pos_roots = read_csv("data/pos_roots.csv")
        pos_roots_map = dict(zip(list(pos_roots.word), list(pos_roots.group)))
        pos_roots = set(pos_roots['group'].drop_duplicates())

        # Save this data to redis for later
        rds.set('data:pos-dict', zlib.compress(pickle.dumps(pos_dict)))
        rds.set('data:pos-roots', zlib.compress(pickle.dumps(pos_roots)))
        rds.set('data:pos-roots-map', zlib.compress(pickle.dumps(pos_roots_map)))

# Negative words
try: neg_dict, neg_roots, neg_roots_map
except:
    if rds.exists('data:neg-dict') and rds.exists('data:neg-roots') and rds.exists('data:neg-roots-map'):
        neg_dict = pickle.loads(zlib.decompress(rds.get('data:neg-dict')))
        neg_roots = pickle.loads(zlib.decompress(rds.get('data:neg-roots')))
        neg_roots_map = pickle.loads(zlib.decompress(rds.get('data:neg-roots-map')))
    else:
        # Read in the negative word list(s)
        neg_dict = read_csv("data/neg_list.csv", header=None, names=['word'])
        neg_dict = set(neg_dict['word'])
        neg_roots = read_csv("data/neg_roots.csv")
        neg_roots_map = dict(zip(list(neg_roots.word), list(neg_roots.group)))
        neg_roots = set(neg_roots['group'].drop_duplicates())

        # Save this data to redis for later
        rds.set('data:neg-dict', zlib.compress(pickle.dumps(neg_dict)))
        rds.set('data:neg-roots', zlib.compress(pickle.dumps(neg_roots)))
        rds.set('data:neg-roots-map', zlib.compress(pickle.dumps(neg_roots_map)))

# 2of12inf dictionary
try: dict_2of12inf
except:
    if rds.exists('data:2of12inf'):
        dict_2of12inf = pickle.loads(zlib.decompress(rds.get('data:2of12inf')))
    else:
        # Read in the 2of12inf
        dict_2of12inf = read_csv("data/2of12inf.txt", header=None, names=['word'])

        # Iterate through and remove the percent signs
        regex = re.compile(r'%$')
        dict_2of12inf.apply(lambda x: re.sub(regex, r'', x['word']), axis=1)
        dict_2of12inf = set(dict_2of12inf['word'])

        # Save this to redis for later
        rds.set('data:2of12inf', zlib.compress(pickle.dumps(dict_2of12inf)))
# Out:
# CPU times: user 6min 34s, sys: 13.9 s, total: 6min 48s
# Wall time: 6min 51s

# %%
del data, df

# %%
# %%capture

# Remove any duplicates where CUSIP, PERMNO, and CIK match
ciks = data.drop_duplicates(subset=['CUSIP', 'PERMNO', 'cik'])

# Only keep the cik and ticker column
ciks = ciks[['cik', 'tic']]

# Iterate over each CIK and pull the relevant 10k filings
crawler = SecCrawler()
end_date = '20081231'
count = '20'

for index, row in ciks.iterrows():
    cik = row.iloc[0]
    tic = row.iloc[1]
    crawler.filing_10K(tic, cik, end_date, count)

# %%
# %%cython
# from cpython cimport bool
#
# from __main__ import rds
#
# def check_redis(str cleaned_key, str processed_key, str report_key):
#     cdef bool processed = False
#     cdef bool cleaned = False
#     cdef str mtime
#
#     if not rds.exists(cleaned_key):
#         if not rds.exists(processed_key):
#             # Temporary check to see if this file has been processed fully
#             if rds.exists(report_key):
#                 mtime = rds.hget(report_key, 'mtime')
#
#                 if not rds.hexists(report_key, 'company_data'):
#                     # Hasn't been cleaned with the new algorithm, so keep booleans False
#                     pass
#                 elif rds.hexists(report_key, 'hist_ret'):
#                     processed = True
#                     cleaned = True
#
#                     # Save to proper place in redis
#                     rds.set(cleaned_key, mtime)
#                     rds.set(processed_key, mtime)
#                 else:
#                     cleaned = True
#
#                     # Save to proper place in redis
#                     rds.set(cleaned_key, mtime)
#         else:
#             processed = True
#     else:
#         # Check to see if this has really been cleaned (company_data exists)
#         if rds.hexists(report_key, 'company_data'):
#             cleaned = True
#             if rds.exists(processed_key):
#                 processed = True
#
#     return (cleaned, processed)

# %%
# %%cython
# import os
#
# def move_file(fh, str fn, str folder, str tic, str cik, str filename, str message):
#     # Generate the new name of the file
#     cdef str s = os.sep
#     cdef str new_name = 'data' + s + folder + s + tic + '-' + cik + '-' + filename
#
#     # Close the file so that we can move it
#     fh.close()
#     os.rename(fn, new_name)
#     print(message)

# %%
# %%cython
# import os
# import re
# import time
# import string
# import pickle
# from datetime import datetime as dt
# from lxml import etree
# from io import StringIO
#
# from bs4 import BeautifulSoup as bs
#
# from __main__ import move_file, df, stopwords, rds, dict_2of12inf
#
# from cpython cimport bool
#
# regex = re.compile(r"(.*\.sgml\s+?:\s+?|.*\nFILED AS OF DATE:\s+?)([\d]+?)\n.*", re.S)
#
# # This function handles the cleaning of the 10-K
# def clean(str fn):
#     cdef bool error = False
#
#     cdef str s = os.sep
#     cdef str tic = fn.split(s)[1]
#     cdef str cik = fn.split(s)[2]
#     cdef str filename = fn.split(s)[4]
#     cdef str report_key = "report:" + cik + ":" + fn
#     cdef str cleaned_key = "cleaned:" + cik + ":" + fn
#
#     # Open the file, get all of the content, and then pull it into a parser
#     fh = open(fn, 'r')
#     cdef unicode contents = fh.read()
#
#     # Clean up some of the text to fix malformed HTML before parsing it
#     cdef list malformed_tags = ['ACCEPTANCE-DATETIME', 'TYPE', 'SEQUENCE', 'FILENAME', 'DESCRIPTION']
#     cdef str tag
#     for tag in malformed_tags:
#         # Do a regex that replaces all of these malformed tags in the document
#         regex = re.compile(r"(\n<%s>[^<]*?)\n" % re.escape(tag), re.I)
#         contents = regex.sub(r"\1</%s>\n" % tag, contents)
#
#     # Create the parser
#     parser = etree.HTMLParser()
#     document = etree.parse(StringIO(contents), parser)
#     doc = document.getroot()
#
#     # The document can either have a root node of sec-document or ims-document
#     if doc.xpath('//sec-document') is not None:
#         root = doc.xpath('//sec-document[1]')[0]
#     elif doc.xpath('//ims-document') is not None:
#         root = doc.xpath('//ims-document[1]')[0]
#     elif doc.xpath('//document') is not None:
#         root = doc.xpath('//document[1]')[0]
#     elif doc.xpath('//error') is not None:
#         root = None
#     else:
#         root = None
#
#     if root is None:
#         # Root node error
#         move_file(fh, fn, "_error", tic, cik, filename, "No root or erroneous root node - moved file")
#         error = True
#     if error: return error
#
#     # Check if this is an amended 10-K and throw it out if so
#     type_text = root.xpath('//type/text()')
#     if type_text is None or len(type_text) == 0:
#         move_file(fh, fn, "_error", tic, cik, filename, "Error finding type - moved file")
#         error = True
#     elif type_text[0] == '10-K/A':
#         move_file(fh, fn, "_amended", tic, cik, filename, "Amended 10-K - moved file")
#         error = True
#     if error: return error
#
#     # Get the 'acceptance-datetime' metadata element
#     acc_dt = root.xpath('//acceptance-datetime/text()')
#     if acc_dt is None or len(acc_dt) == 0:
#         header_text = None
#         # If we didn't find an <acceptance-datetime /> element, find the date elsewhere
#         if len(root.xpath('//sec-header/text()')) != 0:
#             header_text = root.xpath('//sec-header/text()')[0]
#         elif len(root.xpath('//ims-header/text()')) != 0:
#             header_text = root.xpath('//ims-header/text()')[0]
#
#         if header_text:
#             filing_dt_text = re.sub(regex, r"\2", header_text)
#         else:
#             move_file(fh, fn, "_error", tic, cik, filename, "Bad filing date - moved file")
#             error = True
#         if error: return error
#     else:
#         # Get the filing date
#         filing_dt_text = acc_dt[0].split('\n', 1)[0][:8]
#
#     filing_dt = dt.strptime(filing_dt_text, '%Y%m%d')
#     filing_ts = time.mktime(filing_dt.timetuple())
#     begin_dt = dt(1995, 1, 1)
#
#     # If the filing date is not within our date range, then move it
#     if begin_dt > filing_dt:
#         move_file(fh, fn, "_outofrange", tic, cik, filename, "Out of date range - moved file.")
#         error = True
#     if error: return error
#
#     # See if we can find stock info for this company on the filing date of the 10-K
#     cdef int index = 0
#     cik_df = None
#     try:
#         index = df.index.get_loc((bytes(cik, 'utf-8'), filing_dt))
#         cik_df = df.ix[bytes(cik, 'utf-8')]
#         price = cik_df.ix[filing_dt, 'PRC']
#         # Now, check if the price of the stock is less than $3.00
#         if price < 3.0:
#             move_file(fh, fn, "_nostockdata", tic, cik, filename, "Price less than $3.00 - moved file.")
#             error = True
#     except (IndexError, KeyError):
#         # We couldn't find the cik or date for this 10-k
#         move_file(fh, fn, "_nostockdata", tic, cik, filename, "No stock data found - moved file.")
#         error = True
#     if error: return error
#
#     # Grab the report
#     cdef str report = ''.join(root.xpath('//document/text')[0].itertext())
#
#     # We will tokenize the text and iterate through each word
#     cdef list tokens = report.split()
#     cdef list keep_tokens = []
#     cdef set stopwords_set = set(stopwords.words('english'))
#     punc_table = str.maketrans("", "", string.punctuation)
#
#     # Filter out words
#     cdef str word
#     for word in tokens:
#         # Quick check to make sure we should keep filtering the word
#         if len(word) != 1:
#             # Strip punctuation from the word first and make it lowercase
#             word = word.translate(punc_table).lower()
#
#             # Add the word to the keep pile if it is not a stopword and if it is in 2of12inf dictionary
#             if word not in stopwords_set and word in dict_2of12inf:
#                 keep_tokens.append(word)
#
#     tokens = keep_tokens
#     report = " ".join(tokens)
#     cdef int total_words = len(tokens)
#
#     # Gather info for report to save into redis
#     report_hash = {
#         'cik': cik,
#         'tic': tic,
#         'path': fn,
#         'file_name': filename,
#         'filing_date': filing_ts,
#         'year': filing_dt.year,
#         'report': report,
#         'total_words': total_words,
#         'company_data': pickle.dumps(cik_df),
#         'index': index,
#         'mtime': time.time()
#     }
#
#     # Close the file handle
#     fh.close()
#
#     # Save the stuff to redis
#     print("Saving to redis: " + report_key)
#     rds.hmset(report_key, report_hash)
#     rds.set(cleaned_key, time.time())

# %%
# %%cython
# import os
# import pickle
# import math
# import time
# from datetime import datetime as dt
#
# import pandas as pd
# from pandas import DataFrame, Series
#
# from collections import defaultdict
#
# from __main__ import df, rds, pos_dict, pos_roots, pos_roots_map, neg_dict, neg_roots, neg_roots_map
#
# from cpython cimport bool
#
# def process(str fn):
#
#     cdef str s = os.sep
#     cdef str tic = fn.split(s)[1]
#     cdef str cik = fn.split(s)[2]
#     cdef str report_key = "report:" + cik + ":" + fn
#     cdef str processed_key = "processed:"+ cik + ":" + fn
#
#     # Get the report out of redis
#     #print("Found in redis: " + report_key)
#     cdef str report = str(rds.hget(report_key, 'report'))
#     filing_dt = dt.fromtimestamp(int(float(rds.hget(report_key, 'filing_date').decode('utf-8'))))
#     cik_df = pickle.loads(rds.hget(report_key, 'company_data'))
#     cdef int index = int(rds.hget(report_key, 'index'))
#     cdef dict report_hash = {}
#
#     # Now that everything is cleaned up, we can run the word processing algorithm
#     pos_occurs = defaultdict(int)
#     neg_occurs = defaultdict(int)
#     negators = pd.Series(['not', 'no', 'never'])
#
#     # We will tokenize the text and iterate through each word
#     tokens = pd.Series(report.split())
#
#     # Now, process the text
#     cdef int i
#     cdef str token, root, word
#     cdef bool negated
#     for i, token in tokens.iteritems():
#         if token in pos_dict:
#             # Check to see if there is a negator
#             negated = False
#             for word in tokens.iloc[(i - 3):(i + 3)]:
#                 if word in negators.values:
#                     #print("Found a negator: " + word + " - " + token)
#                     negated = True
#             if not negated:
#                 root = pos_roots_map[token]
#                 pos_occurs[root] += 1
#         elif token in neg_dict:
#             # Check to see if there is a negator
#             negated = False
#             for word in tokens.iloc[(i - 3):(i + 3)]:
#                 if word in negators.values:
#                     #print("Found a negator: " + word + " - " + token)
#                     negated = True
#             if not negated:
#                 root = neg_roots_map[token]
#                 neg_occurs[root] += 1
#
#     # For the roots we didn't find, set frequency to zero
#     for root in pos_roots:
#         if root not in pos_occurs:
#             pos_occurs[root] = 0
#     for root in neg_roots:
#         if root not in neg_occurs:
#             neg_occurs[root] = 0
#
#     # Use the index we found earlier to grab the historical info
#     hist_returns = cik_df.ix[(index + 1):, 'RET']
#
#     # Calculate the historical return before the filing date
#     cdef float hist_ret = 1.0
#     for col, series in hist_returns.iteritems():
#         if col == 'RET':
#             for r in series:
#                 if not math.isnan(r):
#                     hist_ret *= (r + 1.0)
#     hist_ret = hist_ret - 1.0
#     #print("Historical return: " + str(hist_ret))
#
#     # Use the index we found earlier to grab the four day window returns
#     returns = cik_df.ix[(index - 3):(index + 1), ['RET','vwretd']]
#
#     # Calculate the abnormal return: r_i = M{t=0, 3} (ret_i,j) - M{t=0,3} (ret_vwi,t)
#     cdef float ret = 1.0
#     cdef float ret_vwi = 1.0
#     for col, series in returns.iteritems():
#         if col == 'RET':
#             for r in series:
#                 if not math.isnan(r):
#                     ret *= (r + 1.0)
#         elif col == 'vwretd':
#             for r in series:
#                 if  not math.isnan(r):
#                     ret_vwi *= (r + 1.0)
#     cdef float ab_ret = ((ret - 1.0) - (ret_vwi - 1.0))
#     #print("Abnormal return: " + str(ab_ret))
#
#     # Save results of text processing to key in redis
#     report_hash['pos_occurs'] = pickle.dumps(pos_occurs)
#     report_hash['neg_occurs'] = pickle.dumps(neg_occurs)
#     report_hash['hist_ret'] = hist_ret
#     report_hash['ab_ret'] = ab_ret
#     report_hash['mtime'] = time.time()
#
#     print("Saving to redis: " + report_key)
#     rds.hmset(report_key, report_hash)
#     rds.set(processed_key, time.time())

# %%
# %%cython
# import os
#
# from __main__ import check_redis, clean, process
#
# from cpython cimport bool
#
# # This is for testing
# cdef int count = 1
# cdef int stop = 100000
# cdef bool skip_cleaned = True
# cdef bool skip_processed = True
# cdef bool process_file = True
#
# cdef dict report_hash
# cdef str fn, s, tic, cik, cleaned_key, processed_key, report_key
# cdef bool cleaned, processed, error
#
# cdef str dirpath
# cdef list dirnames, filenames
# cdef str folder = "SEC-Edgar-data"
# for (dirpath, dirnames, filenames) in os.walk(folder, topdown=False):
#     for filename in filenames:
#         report_hash = {}
#         fn = os.sep.join([dirpath, filename])
#
#         if filename.endswith('.txt'):# and filename == "0000950116-97-000637.txt":
#             if count > stop:
#                 break
#             print(fn)
#             s = os.sep
#             tic = fn.split(s)[1]
#             cik = fn.split(s)[2]
#
#             # Check redis to see if we have processed or cleaned the report already
#             cleaned_key = "cleaned:" + cik + ":" + fn
#             processed_key = "processed:" + cik + ":" + fn
#             report_key = "report:" + cik + ":" + fn
#             (cleaned, processed) = check_redis(cleaned_key, processed_key, report_key)
#
#             # If the report has been cleaned or we don't want to clean it anyway, skip this step
#             error = False
#             if not cleaned or not skip_cleaned:
#                 print("(" + str(count) + ") Cleaning " + fn)
#                 error = clean(fn)
#
#                 if not process and not error:
#                     count += 1
#                     continue
#             if error: continue
#
#             # After possibly cleaning, check if we should process the file
#             if (not processed or not skip_processed) and process_file:
#                 print("(" + str(count) + ") Processing " + fn)
#                 process(fn)
#
#                 count += 1

# %%
count = 0
stop = math.inf
yearly_data = {}

if rds.exists("yearly-data"):
    print("Found yearly data in Redis.")
    yearly_data = pickle.loads(zlib.decompress(rds.get("yearly-data")))
else:
    keys = rds.keys("report:*")
    errors = []
    for key in keys:

        if count >= stop:
            break

        report_hash = rds.hgetall(key)
        try:
            year = 1
            cik = str(report_hash[b'cik'].decode('utf-8'))
            fn = str(report_hash[b'path'].decode('utf-8'))
            key = "report:" + cik + ":" + fn
            pos_occurs = pickle.loads(report_hash[b'pos_occurs'])
            neg_occurs = pickle.loads(report_hash[b'neg_occurs'])
            year = int(report_hash[b'year'])
            total_words = int(report_hash[b'total_words'])
            hist_ret = float(report_hash[b'hist_ret'])
            ab_ret = float(report_hash[b'ab_ret'])

            if total_words == 0:
                # Not sure why this would be zero, but we may need to reprocess
                print("Error with: " + key)
                cleaned_key = "cleaned:" + cik + ":" + fn
                processed_key = "processed:" + cik + ":" + fn

                # Delete this error from redis
                rds.delete(cleaned_key, processed_key, key)

                errors.append(key)
                continue

            try: yearly_data[year]
            except KeyError:
                yearly_data[year] = []

            year_list = yearly_data[year]
            year_list.append({
                'pos_occurs': pos_occurs,
                'neg_occurs': neg_occurs,
                'total_words': total_words,
                'hist_ret': hist_ret,
                'ab_ret': ab_ret
            })
            yearly_data[year] = year_list

            count += 1
        except KeyError:
            continue
        except e:
            print(e)
            
    print("Saving yearly data in Redis.")
    rds.set("yearly-data", zlib.compress(pickle.dumps(yearly_data)))
    
    if len(errors) > 0:
        print("Total errors: " + str(len(errors)))
        
for year in sorted(yearly_data.keys()):
    print(year, len(yearly_data[year]))
# Out:
# Found yearly data in Redis.
# 1996 2502
# 1997 3652
# 1998 3994
# 1999 3792
# 2000 3882
# 2001 3208
# 2002 2619
# 2003 2684
# 2004 3038
# 2005 2913
# 2006 2949
# 2007 2986
# 2008 2727

# %%
rds.exists("regression:" + str(1997))
# Out:
# True

# %%
# %%cython
# import os
# import pickle
#
# import pandas as pd
# from pandas import DataFrame, Series
#
# import statsmodels.api as sm
#
# from __main__ import rds, yearly_data
#
# from cpython cimport bool
#
# cdef int start = 1997
# cdef int end = 2008
# cdef bool skip_regression = True
# cdef bool skip_building = True
# cdef int t
# cdef int year
# cdef int count
# cdef int total
# cdef str key
#
# # Clear some variables so we have enough RAM...
# #try: del data, df
# #except NameError:
# #    pass
#
# # Generate a rolling training model using data up until year T-1
# for t in range(start, (end + 1)):
#
#     print("Analyzing year " + str(t))
#
#     # Skip this analysis if redis already has it and the boolean is set to skip
#     if rds.exists("regression:" + str(t)) and skip_regression:
#         continue
#
#     pos_word_weights = pd.DataFrame()
#     neg_word_weights = pd.DataFrame()
#     hist_returns = pd.DataFrame()
#     ab_returns = pd.DataFrame()
#
#     # Iterate over each year before year T and build the training data set
#     for year in range((start - 1), t):
#
#         key = "regression-data:" + str(year)
#
#         if rds.exists(key) and skip_building:
#             # Extract the data
#             pos_word_weights = pickle.loads(rds.hget(key, 'pos_word_weights'))
#             neg_word_weights = pickle.loads(rds.hget(key, 'neg_word_weights'))
#             hist_returns = pickle.loads(rds.hget(key, 'hist_returns'))
#             ab_returns = pickle.loads(rds.hget(key, 'ab_returns'))
#             continue
#
#         print("Building year " + str(year) + "/" + str(t))
#
#         try: yearly_data[year]
#         except KeyError:
#             print("Year " + str(year) + " not found.")
#             continue
#
#         # Iterate through each 10-K info for the year and generate the dataframe for the regression
#         count = 0
#         total = len(yearly_data[year])
#         for report in yearly_data[year]:
#             count += 1
#             print("Report " + str(count) + "/" + str(total))
#
#             a = report['total_words']
#             hist_ret = report['hist_ret']
#             ab_ret = report['ab_ret']
#
#             weights = {}
#             pos_occurs = report['pos_occurs']
#             for word in pos_occurs.keys():
#                 F = pos_occurs[word]
#                 weights[word] = F/(a * 1.0)
#             pos_word_weights = pos_word_weights.append(weights, ignore_index=True)
#
#             weights = {}
#             neg_occurs = report['neg_occurs']
#             for word in neg_occurs.keys():
#                 F = neg_occurs[word]
#                 weights[word] = F/(a * 1.0)
#             neg_word_weights = neg_word_weights.append(weights, ignore_index=True)
#
#             hist_returns = hist_returns.append({'hist_ret': hist_ret}, ignore_index=True)
#             ab_returns = ab_returns.append({'ab_ret': ab_ret}, ignore_index=True)
#
#         # Save our progress so we don't have to recalculate this year again
#         # This will cont
#         print("Saving progress for year " + str(year) + " to redis.")
#         reg_data_hash = {
#             'pos_word_weights': pickle.dumps(pos_word_weights),
#             'neg_word_weights': pickle.dumps(neg_word_weights),
#             'hist_returns': pickle.dumps(hist_returns),
#             'ab_returns': pickle.dumps(ab_returns)
#         }
#         rds.hmset(key, reg_data_hash)
#
#     # Run the regressions for all years up to year T
#     if not ab_returns.empty and not hist_returns.empty and not pos_word_weights.empty and not neg_word_weights.empty:
#         hist_returns.reset_index()
#         hist_returns_series = pd.Series(hist_returns['hist_ret'])
#         ab_returns.reset_index()
#         ab_returns_series = pd.Series(ab_returns['ab_ret'])
#         pos_word_weights.reset_index()
#         neg_word_weights.reset_index()
#
#         # Estimate the weights for the words using a regression
#         print("T = " + str(t) + ": Estimating weights")
#         pos_reg = sm.OLS(hist_returns_series, pos_word_weights)
#         pos_model = pos_reg.fit()
#         neg_reg = sm.OLS(hist_returns_series, neg_word_weights)
#         neg_model = neg_reg.fit()
#
#         # Map the words to their coefficients
#         pos_coeffs_dict = dict(zip(list(pos_word_weights.columns), pos_model.params))
#         pos_coeffs = pd.DataFrame(list(pos_coeffs_dict.items()), columns=['word','weight'])
#         neg_coeffs_dict = dict(zip(list(neg_word_weights.columns), neg_model.params))
#         neg_coeffs = pd.DataFrame(list(neg_coeffs_dict.items()), columns=['word','weight'])
#
#         # Calculate the average word weight as well as the standard deviation
#         pos_avg = pos_coeffs['weight'].mean()
#         pos_std = pos_coeffs['weight'].std()
#         neg_avg = neg_coeffs['weight'].mean()
#         neg_std = neg_coeffs['weight'].std()
#         #print("Average: " + str(pos_avg) + "; StdDev: " + str(pos_std))
#         #print("Average: " + str(neg_avg) + "; StdDev: " + str(neg_std))
#         #print(pos_coeffs)
#
#         # Normalize the weights of the words
#         print("T = " + str(t) + ": Normalizing weights")
#         pos_norm = list()
#         for col, series in pos_coeffs.iteritems():
#             if col == 'weight':
#                 for weight in series:
#                     pos_norm.append((weight - pos_avg) / pos_std)
#         pos_coeffs['norm_weight'] = pd.Series(pos_norm, index=pos_coeffs.index)
#
#         neg_norm = list()
#         for col, series in neg_coeffs.iteritems():
#             if col == 'weight':
#                 for weight in series:
#                     neg_norm.append((weight - neg_avg) / neg_std)
#         neg_coeffs['norm_weight'] = pd.Series(neg_norm, index=neg_coeffs.index)
#
#         # Iterate through the original word weights and apply the normalized weight
#         for word, series in pos_word_weights.iteritems():
#             norm_weight = pos_coeffs.loc[pos_coeffs['word'] == word]['norm_weight']
#             pos_word_weights[word] = series.apply(lambda x: x * norm_weight)
#         for word, series in neg_word_weights.iteritems():
#             norm_weight = neg_coeffs.loc[neg_coeffs['word'] == word]['norm_weight']
#             neg_word_weights[word] = series.apply(lambda x: x * norm_weight)
#
#         # Run the regression for abnormal (after filing) returns using the estimated weights for the words
#         print("T = " + str(t) + ": Doing regression")
#         pos_ab_reg = sm.OLS(ab_returns_series, pos_word_weights)
#         pos_ab_model = pos_ab_reg.fit()
#         neg_ab_reg = sm.OLS(ab_returns_series, neg_word_weights)
#         neg_ab_model = neg_ab_reg.fit()
#
#         # Map the words to their coefficients
#         pos_coeffs_dict = dict(zip(list(pos_word_weights.columns), pos_ab_model.params))
#         pos_coeffs = pd.DataFrame(list(pos_coeffs_dict.items()), columns=['word','weight'])
#         neg_coeffs_dict = dict(zip(list(neg_word_weights.columns), neg_ab_model.params))
#         neg_coeffs = pd.DataFrame(list(neg_coeffs_dict.items()), columns=['word','weight'])
#
#         # Calculate the score of each document using the weights for each word given by the regression
#         # TODO: we should iterate through each report and insert the calculated score for each document right?
#         #score = math.nan
#
#         key = "regression:" + str(t)
#
#         reg_hash = {
#             'pos_model': pickle.dumps(pos_model),
#             'neg_model': pickle.dumps(neg_model),
#             'pos_ab_model': pickle.dumps(pos_ab_model),
#             'neg_ab_model': pickle.dumps(neg_ab_model)
#         }
#
#         rds.hmset(key, reg_hash)

# %%
# This will store the global positive and negative words occurrances
pos_occurs_all = defaultdict(int)
neg_occurs_all = defaultdict(int)

try: yearly_data
except NameError: yearly_data = pickle.loads(zlib.decompress(rds.get('yearly-data')))

if rds.exists("freq:pos:all") and rds.exists("freq:neg:all"):
    pos_occurs_all = pickle.loads(zlib.decompress(rds.get("freq:pos:all")))
    neg_occurs_all = pickle.loads(zlib.decompress(rds.get("freq:neg:all")))
else:
    for year in yearly_data:
        print("Counting frequency for year " + str(year))

        pos_occurs_year = defaultdict(int)
        neg_occurs_year = defaultdict(int)
        pos_key = "freq:pos:" + str(year)
        neg_key = "freq:neg:" + str(year)

        if rds.exists(pos_key) and rds.exists(neg_key):
            pos_occurs_year = pickle.loads(zlib.decompress(rds.get(pos_key)))
            neg_occurs_year = pickle.loads(zlib.decompress(rds.get(neg_key)))
        else:
            count = 0
            total = len(yearly_data[year])
            for report in yearly_data[year]:
                count += 1
                print("Counting Report " + str(count) + "/" + str(total))
                report_pos_occurs = report['pos_occurs']
                report_neg_occurs = report['neg_occurs']

                for word, freq in report_pos_occurs.items():
                    pos_occurs_year[word] += freq
                for word, freq in report_neg_occurs.items():
                    neg_occurs_year[word] += freq

            print("Saving progress to Redis.")
            rds.set("freq:pos:" + str(year), zlib.compress(pickle.dumps(pos_occurs_year)))
            rds.set("freq:neg:" + str(year), zlib.compress(pickle.dumps(neg_occurs_year)))

    for word, freq in pos_occurs_year.items():
        pos_occurs_all[word] += freq
    for word, freq in neg_occurs_year.items():
        neg_occurs_all[word] += freq
        
    print("Finished totaling and now saving to Redis.")
    rds.set("freq:pos:all", zlib.compress(pickle.dumps(pos_occurs_all)))
    rds.set("freq:neg:all", zlib.compress(pickle.dumps(neg_occurs_all)))

# Sort the values by highest to lowest
pos_sorted = pd.Series(data=pos_occurs_all).sort_values()
neg_sorted = pd.Series(data=neg_occurs_all).sort_values()

# Get the coefficients
pos_coeffs = pickle.loads(zlib.decompress(rds.hget("regression:2008", 'pos_coeffs')))
neg_coeffs = pickle.loads(zlib.decompress(rds.hget("regression:2008", 'neg_coeffs')))

# Place the weights into quintiles
pos_wt_buckets = pd.qcut(pos_coeffs['weight'], 5, labels=range(1,6))
neg_wt_buckets = pd.qcut(neg_coeffs['weight'], 5, labels=range(1,6))

# Sort the coefficients by value
pos_coeffs.sort_values('weight', inplace=True)
neg_coeffs.sort_values('weight', inplace=True)

# See if we have the total 10-Ks and number of appearances of each word in a 10-k
try: total, pos_appearances, neg_appearances
except NameError:
    (total, pos_appearances, neg_appearances) = get_appearances()

# Place the frequencies into quintiles
pos_freq_buckets = pd.qcut(pos_appearances['apps'], 5, labels=range(1,6))
neg_freq_buckets = pd.qcut(neg_appearances['apps'], 5, labels=range(1,6))

bucket_freq_list = []
bucket_wt_list = []
freq_list = []
total_list = []
for (word, row) in pos_coeffs.iterrows():
    bucket_freq_list.append(pos_freq_buckets.ix[word])
    bucket_wt_list.append(pos_wt_buckets.ix[word])
    freq_list.append(pos_sorted.ix[word])
    total_list.append(pos_appearances.ix[word]['apps'])
pos_coeffs['bucket_freq'] = pd.Series(bucket_freq_list, index=pos_coeffs.index)
pos_coeffs['bucket_weight'] = pd.Series(bucket_wt_list, index=pos_coeffs.index)
pos_coeffs['freq'] = pd.Series(freq_list, index=pos_coeffs.index)
pos_coeffs['apps'] = pd.Series(total_list, index=pos_coeffs.index)
pos_coeffs['files'] = pos_appearances['files']

bucket_freq_list = []
bucket_wt_list = []
freq_list = []
total_list = []
for (word, row) in neg_coeffs.iterrows():
    bucket_freq_list.append(neg_freq_buckets.ix[word])
    bucket_wt_list.append(neg_wt_buckets.ix[word])
    freq_list.append(neg_sorted.ix[word])
    total_list.append(neg_appearances.ix[word]['apps'])
neg_coeffs['bucket_freq'] = pd.Series(bucket_freq_list, index=neg_coeffs.index)
neg_coeffs['bucket_weight'] = pd.Series(bucket_wt_list, index=neg_coeffs.index)
neg_coeffs['freq'] = pd.Series(freq_list, index=neg_coeffs.index)
neg_coeffs['apps'] = pd.Series(total_list, index=neg_coeffs.index)
neg_coeffs['files'] = neg_appearances['files']

# Build the table of weight quintiles to frequency quintiles
pos_tab5 = pos_coeffs.reset_index(level='word').set_index(['bucket_weight','bucket_freq','word'])
neg_tab5 = neg_coeffs.reset_index(level='word').set_index(['bucket_weight','bucket_freq','word'])

# Iterate first through the weight buckets
print("Positive Weight Quintiles by Term Frequency Quintiles")
for i in range(1,6):
    # Get the total number of words in this weight quantile
    tot_in_quantile = len(pos_tab5.ix[i]['weight'])
    
    print("\nWeight Quintile " + str(i) + ": Total words = " + str(tot_in_quantile))
    
    # Find the number of words in each freq bucket and show that as percentage of words in weight bucket
    for j in range(1,6):
        num_words = len(pos_tab5.ix[(i,j)]['weight'])
        perc = (num_words / (1.0 * tot_in_quantile)) * 100
        print("Term Freq Quintile " + str(j) + ": " + str(perc))
        
print("\nNegative Weight Quintiles by Term Frequency Quintiles")
for i in range(1,6):
    tot_in_quantile = len(neg_tab5.ix[i]['weight'])
    
    print("\nWeight Quintile " + str(i) + ": Total words = " + str(tot_in_quantile))
    
    for j in range(1,6):
        num_words = len(neg_tab5.ix[(i,j)]['weight'])
        perc = (num_words / (1.0 * tot_in_quantile)) * 100
        print("Term Freq Quintile " + str(j) + ": " + str(perc))


# Now, sort by the frequency buckets (ascending) and weights (descending)
pos_coeffs.sort_values(['bucket_freq','weight'], ascending=[True,False], inplace=True)
neg_coeffs.sort_values(['bucket_freq','weight'], ascending=[True,False], inplace=True)

# Get the top 5 words in each quintile
pos_top5 = pos_coeffs.reset_index(level=['word']).set_index(['bucket_freq'])
pos_top5_list = {}
neg_top5 = neg_coeffs.reset_index(level=['word']).set_index(['bucket_freq'])
neg_top5_list = {}
for i in range(1, 6):
    pos_words = []
    pos_bucket_words = pos_top5.ix[i]['word']
    neg_words = []
    neg_bucket_words = neg_top5.ix[i]['word']
    
    count = 0
    for word in pos_bucket_words:
        if count >= 5:
            break
        pos_words.append(word)
        count += 1
    count = 0
    for word in neg_bucket_words:
        if count >= 5:
            break
        neg_words.append(word)
        count += 1
    
    pos_top5_list[i] = pos_words
    neg_top5_list[i] = neg_words

# Print out most frequent positive words
header = "Top Five Most Positive and Negative Words within Frequency Quintiles"
print(header)
print("="*len(header))

subheader = "\nTop 5 Most Positive Words"
print(subheader)
print("="*len(subheader))

for (bucket, words) in pos_top5_list.items():
    print("\nBucket " + str(bucket))
    for word in words:
        print(word)

# Print out most frequent negative words
subheader = "\nTop 5 Most Negative Words"
print(subheader)
print("="*len(subheader))

for (bucket, words) in neg_top5_list.items():
    print("\nBucket " + str(bucket))
    for word in words:
        print(word)

# %%
def get_appearances():
    try: yearly_data
    except NameError: yearly_data = pickle.loads(zlib.decompress(rds.get("yearly-data")))

    pos_appearances_dict = defaultdict(int)
    neg_appearances_dict = defaultdict(int)
    pos_app_set = {}
    neg_app_set = {}    

    total = 0
    for year in yearly_data:
        total += len(yearly_data[year])

        i = 0
        for report in yearly_data[year]:
            # Keep track if a word appears at least once and increment a counter if so
            pos_occurs = report['pos_occurs']
            neg_occurs = report['neg_occurs']

            for (word, freq) in pos_occurs.items():
                try: word_set = pos_app_set[word]
                except: word_set = set()
                    
                if freq > 0:
                    pos_appearances_dict[word] += 1
                    word_set.add(str(year) + ":" + str(i))
                    pos_app_set[word] = word_set
                else:
                    pos_appearances_dict[word] += 0
                    pos_app_set[word] = word_set
                    
            for (word, freq) in neg_occurs.items():
                if freq > 0:
                    neg_appearances_dict[word] += 1
                    word_set.add(str(year) + ":" + str(i))
                    neg_app_set[word] = word_set
                else:
                    neg_appearances_dict[word] += 0
                    neg_app_set[word] = word_set
            i += 1

    pos_appearances = pd.DataFrame({'apps': pos_appearances_dict, 'files': pos_app_set})
    neg_appearances = pd.DataFrame({'apps': neg_appearances_dict, 'files': neg_app_set})
    return (total, pos_appearances, neg_appearances)

#get_appearances()

# %%
del total, pos_appearances, neg_appearances

# %%
from WordPower import WordPower

#start = 1995
start = 2008
end = 2008

if __name__ == '__main__':
    try: wp
    except NameError: wp = WordPower(start, end)

    print("Loading data...")
    wp.load_data()

    print("Scraping SEC Edgar website for 10-Ks...")
    wp.scrape_edgar()
# Out:
# Loading data...
# Loading data:crsp-comp:2008-2008 from Redis.
# Loading data:pos-dict, data:pos-roots, and data:pos-roots-map from Redis.
# Loading data:neg-dict, data:neg-roots, and data:neg-roots-map from Redis.
# Loading data:2of12inf from Redis.
# Scraping SEC Edgar website for 10-Ks...
# *Crawler filing_10K: b'0000748015' - b'ZZ'
# *Crawler filing_10K: b'0001352341' - b'VRGY'
# *Crawler filing_10K: b'0001382911' - b'OREX'
# *Crawler filing_10K: b'0000912892' - b'TV'
# *Crawler filing_10K: b'0000072331' - b'NDSN'
# *Crawler filing_10K: b'0000771729' - b'AAIIQ'
# *Crawler filing_10K: b'0000070318' - b'THC'
# *Crawler filing_10K: b'0000911583' - b'LVB'
# *Crawler filing_10K: b'0001128928' - b'FLO'
# *Crawler filing_10K: b'0001402829' - b'ORN'
# *Crawler filing_10K: b'0000946823' - b'VTNC'
# *Crawler filing_10K: b'0000885074' - b'ADAT'
# *Crawler filing_10K: b'0000072207' - b'NBL'
# *Crawler filing_10K: b'0001138804' - b'UNCA'
# *Crawler filing_10K: b'0000764244' - b'INTV'
# *Crawler filing_10K: b'0000839470' - b'URRE'
# *Crawler filing_10K: b'0001034088' - b'ECLP'
# *Crawler filing_10K: b'0001289419' - b'MORN'
# *Crawler filing_10K: b'0000866830' - b'ENTN'
# *Crawler filing_10K: b'0000314132' - b'FLTWQ'
# *Crawler filing_10K: b'0000089439' - b'MLI'
# *Crawler filing_10K: b'0000040570' - b'JOB'
# *Crawler filing_10K: b'0000922863' - b'QLTY'
# *Crawler filing_10K: b'0001063561' - b'PZZ'
# *Crawler filing_10K: b'0001388133' - b'SHOR'
# *Crawler filing_10K: b'0001029506' - b'RAH'
# *Crawler filing_10K: b'0001107216' - b'ORCH'
# *Crawler filing_10K: b'0001000229' - b'CLB'
# *Crawler filing_10K: b'0000769397' - b'ADSK'
# *Crawler filing_10K: b'0000880446' - b'VTSS'
# *Crawler filing_10K: b'0000003453' - b'MATX'
# *Crawler filing_10K: b'0000056806' - b'KRSL'
# *Crawler filing_10K: b'0000093456' - b'SRCTQ'
# *Crawler filing_10K: b'0000317540' - b'COKE'
# *Crawler filing_10K: b'0000847935' - b'ALLI'
# *Crawler filing_10K: b'0000110471' - b'WWW'
# *Crawler filing_10K: b'0001065332' - b'EGOV'
# *Crawler filing_10K: b'0000946770' - b'DTEGY'
# *Crawler filing_10K: b'0001159154' - b'RJET'
# *Crawler filing_10K: b'0001393718' - b'DSP'
# *Crawler filing_10K: b'0001084765' - b'RECN'
# *Crawler filing_10K: b'0000009892' - b'BCR'
# *Crawler filing_10K: b'0001345840' - b'HUGH'
# *Crawler filing_10K: b'0001116132' - b'COH'
# *Crawler filing_10K: b'0000068270' - b'RT'
# *Crawler filing_10K: b'0001161611' - b'ACH'
# *Crawler filing_10K: b'0000795615' - b'PCZ'
# *Crawler filing_10K: b'0000933405' - b'ATAC'
# *Crawler filing_10K: b'0001121484' - b'OIS'
# *Crawler filing_10K: b'0001041061' - b'YUM'
# *Crawler filing_10K: b'0000720896' - b'MRY'
# *Crawler filing_10K: b'0000835887' - b'PGNX'
# *Crawler filing_10K: b'0001002902' - b'VEXPQ'
# *Crawler filing_10K: b'0000024741' - b'GLW'
# *Crawler filing_10K: b'0001023514' - b'HMY'
# *Crawler filing_10K: b'0000315374' - b'HURC'
# *Crawler filing_10K: b'0001060009' - b'KND'
# *Crawler filing_10K: b'0001356104' - b'MLNX'
# *Crawler filing_10K: b'0000800937' - b'NSANY'
# *Crawler filing_10K: b'0001104855' - b'SPRT'
# *Crawler filing_10K: b'0000894405' - b'ARCB'
# *Crawler filing_10K: b'0001092013' - b'ACME'
# *Crawler filing_10K: b'0001299139' - b'TEAR'
# *Crawler filing_10K: b'0001029581' - b'MDSY'
# *Crawler filing_10K: b'0000071829' - b'NR'
# *Crawler filing_10K: b'0000897448' - b'AMRN'
# *Crawler filing_10K: b'0000355999' - b'ESND'
# *Crawler filing_10K: b'0001094739' - b'FNSR'
# *Crawler filing_10K: b'0001102741' - b'STEC'
# *Crawler filing_10K: b'0000948844' - b'PLNTQ'
# *Crawler filing_10K: b'0001108320' - b'SMTX'
# *Crawler filing_10K: b'0000928421' - b'MTSN'
# *Crawler filing_10K: b'0000100517' - b'UAL'
# *Crawler filing_10K: b'0001342126' - b'MHGC'
# *Crawler filing_10K: b'0001384072' - b'VNR'
# *Crawler filing_10K: b'0001350381' - b'INWK'
# *Crawler filing_10K: b'0000354655' - b'BOLT'
# *Crawler filing_10K: b'0000746834' - b'NGAS'
# *Crawler filing_10K: b'0000948846' - b'AAI'
# *Crawler filing_10K: b'0001397516' - b'REXX'
# *Crawler filing_10K: b'0000030625' - b'FLS'
# *Crawler filing_10K: b'0000863436' - b'BHE'
# *Crawler filing_10K: b'0001166691' - b'CMCSA'
# *Crawler filing_10K: b'0000886475' - b'CMKG'
# *Crawler filing_10K: b'0001089638' - b'NSTC'
# *Crawler filing_10K: b'0000884247' - b'LBIX'
# *Crawler filing_10K: b'0001336917' - b'UA'
# *Crawler filing_10K: b'0000885988' - b'INMD'
# *Crawler filing_10K: b'0000933034' - b'STRT'
# *Crawler filing_10K: b'0001367880' - b'CHV'
# *Crawler filing_10K: b'0000807707' - b'VOXX'
# *Crawler filing_10K: b'0001383790' - b'SSRX'
# *Crawler filing_10K: b'0000056047' - b'KEX'
# *Crawler filing_10K: b'0000849636' - b'CORX'
# *Crawler filing_10K: b'0001051286' - b'ENSI'
# *Crawler filing_10K: b'0001344708' - b'AMGI'
# *Crawler filing_10K: b'0001116435' - b'AIRV'
# *Crawler filing_10K: b'0000816949' - b'TTG'
# *Crawler filing_10K: b'0000850483' - b'GTSI'
# *Crawler filing_10K: b'0000093859' - b'BH'
# *Crawler filing_10K: b'0001122904' - b'NTGR'
# *Crawler filing_10K: b'0000845289' - b'HNR'
# *Crawler filing_10K: b'0001026655' - b'CMT'
# *Crawler filing_10K: b'0000934280' - b'CYBS'
# *Crawler filing_10K: b'0001041657' - b'ROIAK'
# *Crawler filing_10K: b'0001520262' - b'ALKS'
# *Crawler filing_10K: b'0001017673' - b'DVD'
# *Crawler filing_10K: b'0000775158' - b'OSK'
# *Crawler filing_10K: b'0000077543' - b'TPC'
# *Crawler filing_10K: b'0000097134' - b'TNC'
# *Crawler filing_10K: b'0000864509' - b'MOC'
# *Crawler filing_10K: b'0000889331' - b'LFUS'
# *Crawler filing_10K: b'0000879993' - b'DUSA'
# *Crawler filing_10K: b'0000003952' - b'ADGI'
# *Crawler filing_10K: b'0000940944' - b'DRI'
# *Crawler filing_10K: b'0001163560' - b'GTMAY'
# *Crawler filing_10K: b'0001035884' - b'CTV.1'
# *Crawler filing_10K: b'0001011570' - b'KNL'
# *Crawler filing_10K: b'0000780434' - b'RESP'
# *Crawler filing_10K: b'0000874016' - b'JNY'
# *Crawler filing_10K: b'0001132484' - b'NZ.1'
# *Crawler filing_10K: b'0000110430' - b'FTO'
# *Crawler filing_10K: b'0000353278' - b'NVO'
# *Crawler filing_10K: b'0000804328' - b'QCOM'
# *Crawler filing_10K: b'0001023731' - b'EGHT'
# *Crawler filing_10K: b'0000912615' - b'URBN'
# *Crawler filing_10K: b'0000045876' - b'HSC'
# *Crawler filing_10K: b'0000920033' - b'JOSB'
# *Crawler filing_10K: b'0001158838' - b'ATE'
# *Crawler filing_10K: b'0000045919' - b'HHS'
# *Crawler filing_10K: b'0001257803' - b'TLVTF'
# *Crawler filing_10K: b'0001145197' - b'PODD'
# *Crawler filing_10K: b'0000048898' - b'HUB.B'
# *Crawler filing_10K: b'0000034151' - b'JAS'
# *Crawler filing_10K: b'0000074818' - b'ORBT'
# *Crawler filing_10K: b'0001168351' - b'TRMD'
# *Crawler filing_10K: b'0001408287' - b'ZEP'
# *Crawler filing_10K: b'0001291855' - b'SPCB'
# *Crawler filing_10K: b'0000807863' - b'MITK'
# *Crawler filing_10K: b'0000028452' - b'DEVC'
# *Crawler filing_10K: b'0000821002' - b'GIII'
# *Crawler filing_10K: b'0001018724' - b'AMZN'
# *Crawler filing_10K: b'0000865941' - b'CGI'
# *Crawler filing_10K: b'0001027207' - b'EPIQ'
# *Crawler filing_10K: b'0000070415' - b'GPX'
# *Crawler filing_10K: b'0000200406' - b'JNJ'
# *Crawler filing_10K: b'0001010612' - b'SYKE'
# *Crawler filing_10K: b'0001108329' - b'PTR'
# *Crawler filing_10K: b'0000933454' - b'VOXW'
# *Crawler filing_10K: b'0000828750' - b'GSIC'
# *Crawler filing_10K: b'0000940942' - b'HUBG'
# *Crawler filing_10K: b'0001570585' - b'LBTYK'
# *Crawler filing_10K: b'0000865570' - b'THQIQ'
# *Crawler filing_10K: b'0001014672' - b'CALP'
# *Crawler filing_10K: b'0000845818' - b'RADS'
# *Crawler filing_10K: b'0000707388' - b'DRAD'
# *Crawler filing_10K: b'0000917968' - b'PEET'
# *Crawler filing_10K: b'0000886158' - b'BBBY'
# *Crawler filing_10K: b'0001094005' - b'SINA'
# *Crawler filing_10K: b'0001058444' - b'SVVS'
# *Crawler filing_10K: b'0000003982' - b'ALY'
# *Crawler filing_10K: b'0000874716' - b'IDXX'
# *Crawler filing_10K: b'0001035267' - b'ISRG'
# *Crawler filing_10K: b'0001135644' - b'SIEGY'
# *Crawler filing_10K: b'0001419428' - b'VTGDF'
# *Crawler filing_10K: b'0001173643' - b'TRX'
# *Crawler filing_10K: b'0001180145' - b'CSII'
# *Crawler filing_10K: b'0000906192' - b'SRX'
# *Crawler filing_10K: b'0000020520' - b'FTR'
# *Crawler filing_10K: b'0001347557' - b'PAC'
# *Crawler filing_10K: b'0001090872' - b'A'
# *Crawler filing_10K: b'0001618921' - b'WBA'
# *Crawler filing_10K: b'0001068796' - b'MAXY'
# *Crawler filing_10K: b'0000906326' - b'RURL'
# *Crawler filing_10K: b'0001157377' - b'ABCO'
# *Crawler filing_10K: b'0000008146' - b'ALOT'
# *Crawler filing_10K: b'0001285137' - b'KZ'
# *Crawler filing_10K: b'0001125376' - b'ENSG'
# *Crawler filing_10K: b'0001167379' - b'ACL'
# *Crawler filing_10K: b'0000350199' - b'CACHQ'
# *Crawler filing_10K: b'0000935703' - b'DLTR'
# *Crawler filing_10K: b'0000040704' - b'GIS'
# *Crawler filing_10K: b'0000768892' - b'HAXS'
# *Crawler filing_10K: b'0000003197' - b'CECE'
# *Crawler filing_10K: b'0000746838' - b'UIS'
# *Crawler filing_10K: b'0000202375' - b'LKII'
# *Crawler filing_10K: b'0000276283' - b'ESCC'
# *Crawler filing_10K: b'0000899296' - b'MAD'
# *Crawler filing_10K: b'0000898173' - b'ORLY'
# *Crawler filing_10K: b'0000107687' - b'WGO'
# *Crawler filing_10K: b'0000844059' - b'FRPH'
# *Crawler filing_10K: b'0000016868' - b'CNI'
# *Crawler filing_10K: b'0001136893' - b'FIS'
# *Crawler filing_10K: b'0000750199' - b'EPL'
# *Crawler filing_10K: b'0001385292' - b'TYPE'
# *Crawler filing_10K: b'0000933738' - b'ENG'
# *Crawler filing_10K: b'0001120916' - b'AEZ'
# *Crawler filing_10K: b'0000008670' - b'ADP'
# *Crawler filing_10K: b'0000716006' - b'YRCW'
# *Crawler filing_10K: b'0001139683' - b'BLHI'
# *Crawler filing_10K: b'0000732485' - b'GENZ'
# *Crawler filing_10K: b'0000949158' - b'CRAY'
# *Crawler filing_10K: b'0001394159' - b'OWW'
# *Crawler filing_10K: b'0000909791' - b'UTEK'
# *Crawler filing_10K: b'0001294662' - b'KBXRF'
# *Crawler filing_10K: b'0001101302' - b'ENTG'
# *Crawler filing_10K: b'0000913241' - b'SHOO'
# *Crawler filing_10K: b'0000930803' - b'HAUP'
# *Crawler filing_10K: b'0000050863' - b'INTC'
# *Crawler filing_10K: b'0000875045' - b'BIIB'
# *Crawler filing_10K: b'0001001233' - b'SGMO'
# *Crawler filing_10K: b'0001292470' - b'NHWK'
# *Crawler filing_10K: b'0001163165' - b'COP'
# *Crawler filing_10K: b'0001162461' - b'CUTR'
# *Crawler filing_10K: b'0001022368' - b'SHF'
# *Crawler filing_10K: b'0001094238' - b'HPOL'
# *Crawler filing_10K: b'0001349892' - b'VRCH'
# *Crawler filing_10K: b'0001381325' - b'BBND'
# *Crawler filing_10K: b'0001402175' - b'TOH'
# *Crawler filing_10K: b'0001333141' - b'FMS'
# *Crawler filing_10K: b'0001049108' - b'DTGF'
# *Crawler filing_10K: b'0000850660' - b'THMD'
# *Crawler filing_10K: b'0000800458' - b'RENT'
# *Crawler filing_10K: b'0001038367' - b'PAEGF'
# *Crawler filing_10K: b'0001479920' - b'TBSIQ'
# *Crawler filing_10K: b'0000897075' - b'RPRX'
# *Crawler filing_10K: b'0000948708' - b'SMSI'
# *Crawler filing_10K: b'0001359555' - b'PCO'
# *Crawler filing_10K: b'0000918541' - b'NNBR'
# *Crawler filing_10K: b'0000886744' - b'GERN'
# *Crawler filing_10K: b'0001056923' - b'DTLK'
# *Crawler filing_10K: b'0001372041' - b'PAET'
# *Crawler filing_10K: b'0001051514' - b'MELA'
# *Crawler filing_10K: b'0001062449' - b'BWLD'
# *Crawler filing_10K: b'0000906782' - b'CYDS'
# *Crawler filing_10K: b'0001335793' - b'CXG'
# *Crawler filing_10K: b'0001290476' - b'VBFC'
# *Crawler filing_10K: b'0001010286' - b'FTWRQ'
# *Crawler filing_10K: b'0001119775' - b'MTSXY'
# *Crawler filing_10K: b'0000320575' - b'PES'
# *Crawler filing_10K: b'0000814586' - b'LWAY'
# *Crawler filing_10K: b'0000040545' - b'GE'
# *Crawler filing_10K: b'0000313927' - b'CHD'
# *Crawler filing_10K: b'0001109116' - b'EVC'
# *Crawler filing_10K: b'0000012978' - b'OMX'
# *Crawler filing_10K: b'0000030302' - b'ALCSQ'
# *Crawler filing_10K: b'0001013238' - b'ARDM'
# *Crawler filing_10K: b'0000063276' - b'MAT'
# *Crawler filing_10K: b'0001045150' - b'OPAY'
# *Crawler filing_10K: b'0000103595' - b'VLGEA'
# *Crawler filing_10K: b'0000896429' - b'USAT'
# *Crawler filing_10K: b'0000916540' - b'DAR'
# *Crawler filing_10K: b'0000310568' - b'MSCC'
# *Crawler filing_10K: b'0000916529' - b'ARTX'
# *Crawler filing_10K: b'0000006571' - b'AGL.1'
# *Crawler filing_10K: b'0001138830' - b'AUTH'
# *Crawler filing_10K: b'0000932111' - b'MCRL'
# *Crawler filing_10K: b'0000924822' - b'MLR'
# *Crawler filing_10K: b'0001410056' - b'GRH'
# *Crawler filing_10K: b'0000041133' - b'GRB'
# *Crawler filing_10K: b'0001048695' - b'FFIV'
# *Crawler filing_10K: b'0000886035' - b'BGC'
# *Crawler filing_10K: b'0000018172' - b'CAS'
# *Crawler filing_10K: b'0001005210' - b'SPH'
# *Crawler filing_10K: b'0001046692' - b'JADE'
# *Crawler filing_10K: b'0000929008' - b'WCC'
# *Crawler filing_10K: b'0000093676' - b'SCX'
# *Crawler filing_10K: b'0001003929' - b'VIAP'
# *Crawler filing_10K: b'0001207179' - b'GLNG'
# *Crawler filing_10K: b'0000895041' - b'GLLC'
# *Crawler filing_10K: b'0000002178' - b'AE'
# *Crawler filing_10K: b'0001038683' - b'RYAAY'
# *Crawler filing_10K: b'0000863157' - b'PETM'
# *Crawler filing_10K: b'0001114200' - b'AMMD'
# *Crawler filing_10K: b'0001046880' - b'CEDCQ'
# *Crawler filing_10K: b'0001013488' - b'BJRI'
# *Crawler filing_10K: b'0000901219' - b'HGSI'
# *Crawler filing_10K: b'0001322505' - b'BIOD'
# *Crawler filing_10K: b'0001125920' - b'SFLY'
# *Crawler filing_10K: b'0000063296' - b'MATW'
# *Crawler filing_10K: b'0001002388' - b'ACCL'
# *Crawler filing_10K: b'0000006314' - b'ANEN'
# *Crawler filing_10K: b'0001203464' - b'IAG'
# *Crawler filing_10K: b'0001024519' - b'CNH'
# *Crawler filing_10K: b'0001059262' - b'SP'
# *Crawler filing_10K: b'0001037461' - b'BJ'
# *Crawler filing_10K: b'0000075362' - b'PCAR'
# *Crawler filing_10K: b'0000351998' - b'DAIO'
# *Crawler filing_10K: b'0001310094' - b'ABPI'
# *Crawler filing_10K: b'0001517396' - b'SSYS'
# *Crawler filing_10K: b'0000052795' - b'AXE'
# *Crawler filing_10K: b'0000105634' - b'EME'
# *Crawler filing_10K: b'0000878903' - b'SYNI'
# *Crawler filing_10K: b'0000106640' - b'WHR'
# *Crawler filing_10K: b'0000357020' - b'XCRA'
# *Crawler filing_10K: b'0000926761' - b'CPHC'
# *Crawler filing_10K: b'0001367644' - b'EBS'
# *Crawler filing_10K: b'0001295484' - b'JOBS'
# *Crawler filing_10K: b'0000798528' - b'OMEX'
# *Crawler filing_10K: b'0000028917' - b'DDS'
# *Crawler filing_10K: b'0001021604' - b'OTIV'
# *Crawler filing_10K: b'0001047335' - b'NHC'
# *Crawler filing_10K: b'0001377902' - b'ETELY'
# *Crawler filing_10K: b'0000887733' - b'CENTA'
# *Crawler filing_10K: b'0001324189' - b'TIS'
# *Crawler filing_10K: b'0001057758' - b'TWTC'
# *Crawler filing_10K: b'0000027096' - b'DSCP'
# *Crawler filing_10K: b'0001402606' - b'BCOM'
# *Crawler filing_10K: b'0001340744' - b'ALTUQ'
# *Crawler filing_10K: b'0000320345' - b'MCRS'
# *Crawler filing_10K: b'0001105542' - b'AIRO'
# *Crawler filing_10K: b'0001258021' - b'JEDOF'
# *Crawler filing_10K: b'0001122411' - b'ASX'
# *Crawler filing_10K: b'0000878828' - b'WTT'
# *Crawler filing_10K: b'0000785786' - b'PLXS'
# *Crawler filing_10K: b'0001328650' - b'BRNC'
# *Crawler filing_10K: b'0000897429' - b'CHS'
# *Crawler filing_10K: b'0000945983' - b'WSTG'
# *Crawler filing_10K: b'0001008848' - b'ACOR'
# *Crawler filing_10K: b'0000866121' - b'OA'
# *Crawler filing_10K: b'0001015483' - b'DDMX'
# *Crawler filing_10K: b'0000708781' - b'CASS'
# *Crawler filing_10K: b'0000728535' - b'JBHT'
# *Crawler filing_10K: b'0000066382' - b'MLHR'
# *Crawler filing_10K: b'0001043873' - b'NVDL'
# *Crawler filing_10K: b'0001172222' - b'HA'
# *Crawler filing_10K: b'0001368613' - b'PEX.2'
# *Crawler filing_10K: b'0000040533' - b'GD'
# *Crawler filing_10K: b'0001070985' - b'CXW'
# *Crawler filing_10K: b'0001145404' - b'CRTX'
# *Crawler filing_10K: b'0001405503' - b'STV'
# *Crawler filing_10K: b'0000798949' - b'UNT'
# *Crawler filing_10K: b'0000721371' - b'CAH'
# *Crawler filing_10K: b'0000912728' - b'FWRD'
# *Crawler filing_10K: b'0001049210' - b'VRNM'
# *Crawler filing_10K: b'0000078003' - b'PFE'
# *Crawler filing_10K: b'0000313616' - b'DHR'
# *Crawler filing_10K: b'0000215466' - b'CDE'
# *Crawler filing_10K: b'0001367705' - b'MEDE'
# *Crawler filing_10K: b'0000703361' - b'IDTI'
# *Crawler filing_10K: b'0001011290' - b'NDN'
# *Crawler filing_10K: b'0001407623' - b'ROIC'
# *Crawler filing_10K: b'0000003570' - b'LNG'
# *Crawler filing_10K: b'0000718130' - b'ISYS'
# *Crawler filing_10K: b'0001124804' - b'MDRX'
# *Crawler filing_10K: b'0000856250' - b'CRFT'
# *Crawler filing_10K: b'0001037676' - b'ACI'
# *Crawler filing_10K: b'0000790818' - b'XRIT'
# *Crawler filing_10K: b'0000879884' - b'TTES'
# *Crawler filing_10K: b'0001088162' - b'MCZ'
# *Crawler filing_10K: b'0000718573' - b'RADN'
# *Crawler filing_10K: b'0001036262' - b'INTT'
# *Crawler filing_10K: b'0000859368' - b'MRX'
# *Crawler filing_10K: b'0000868809' - b'XTO'
# *Crawler filing_10K: b'0001108205' - b'CRIS'
# *Crawler filing_10K: b'0000918386' - b'QLGC'
# *Crawler filing_10K: b'0001364099' - b'IPHS'
# *Crawler filing_10K: b'0000793524' - b'REFR'
# *Crawler filing_10K: b'0001124608' - b'RGDXQ'
# *Crawler filing_10K: b'0001372020' - b'GLDD'
# *Crawler filing_10K: b'0001001907' - b'ASTC'
# *Crawler filing_10K: b'0000021344' - b'KO'
# *Crawler filing_10K: b'0000105608' - b'WGA'
# *Crawler filing_10K: b'0000046129' - b'AMOT'
# *Crawler filing_10K: b'0001158041' - b'TRQ'
# *Crawler filing_10K: b'0000854701' - b'ISSI'
# *Crawler filing_10K: b'0000040888' - b'AJRD'
# *Crawler filing_10K: b'0000897723' - b'SANM'
# *Crawler filing_10K: b'0000723125' - b'MU'
# *Crawler filing_10K: b'0000820097' - b'NOIZ'
# *Crawler filing_10K: b'0000929887' - b'APOL'
# *Crawler filing_10K: b'0000865754' - b'SHS'
# *Crawler filing_10K: b'0001129623' - b'ODSY'
# *Crawler filing_10K: b'0001023128' - b'LAD'
# *Crawler filing_10K: b'0001016118' - b'DASTY'
# *Crawler filing_10K: b'0001031203' - b'GPI'
# *Crawler filing_10K: b'0000874238' - b'STRL'
# *Crawler filing_10K: b'0000277928' - b'TIII'
# *Crawler filing_10K: b'0000927993' - b'MRB'
# *Crawler filing_10K: b'0001330017' - b'FMCN'
# *Crawler filing_10K: b'0000948642' - b'TI'
# *Crawler filing_10K: b'0001386716' - b'SBLK'
# *Crawler filing_10K: b'0000880432' - b'MSON'
# *Crawler filing_10K: b'0000091419' - b'SJM'
# *Crawler filing_10K: b'0000896156' - b'ETH'
# *Crawler filing_10K: b'0000318154' - b'AMGN'
# *Crawler filing_10K: b'0000066740' - b'MMM'
# *Crawler filing_10K: b'0001001385' - b'NWPX'
# *Crawler filing_10K: b'0001135017' - b'KMR'
# *Crawler filing_10K: b'0000814361' - b'TBL'
# *Crawler filing_10K: b'0001326973' - b'SMOD'
# *Crawler filing_10K: b'0000033619' - b'ESL'
# *Crawler filing_10K: b'0000757011' - b'USG'
# *Crawler filing_10K: b'0000765258' - b'IMCL.1'
# *Crawler filing_10K: b'0000918608' - b'EGO'
# *Crawler filing_10K: b'0000877212' - b'ZBRA'
# *Crawler filing_10K: b'0001349437' - b'TWER'
# *Crawler filing_10K: b'0000725460' - b'PCGR'
# *Crawler filing_10K: b'0000844143' - b'JOEZ'
# *Crawler filing_10K: b'0000793628' - b'CHNR'
# *Crawler filing_10K: b'0001221715' - b'IOC'
# *Crawler filing_10K: b'0000799167' - b'MRTN'
# *Crawler filing_10K: b'0000823094' - b'BID'
# *Crawler filing_10K: b'0000727207' - b'AXDX'
# *Crawler filing_10K: b'0000897322' - b'GILT'
# *Crawler filing_10K: b'0001287808' - b'HIL'
# *Crawler filing_10K: b'0000104169' - b'WMT'
# *Crawler filing_10K: b'0001365216' - b'SCMP'
# *Crawler filing_10K: b'0000790730' - b'AMN'
# *Crawler filing_10K: b'0000828747' - b'RBI'
# *Crawler filing_10K: b'0001191141' - b'KNMCY'
# *Crawler filing_10K: b'0000788329' - b'JOUT'
# *Crawler filing_10K: b'0001168556' - b'TBV'
# *Crawler filing_10K: b'0001169264' - b'SVR.1'
# *Crawler filing_10K: b'0001410172' - b'RBCN'
# *Crawler filing_10K: b'0001288946' - b'STXXQ'
# *Crawler filing_10K: b'0001324272' - b'RUTH'
# *Crawler filing_10K: b'0000883981' - b'MRT'
# *Crawler filing_10K: b'0001289460' - b'TXRH'
# *Crawler filing_10K: b'0000768411' - b'CYBE'
# *Crawler filing_10K: b'0001029023' - b'SYNM'
# *Crawler filing_10K: b'0000717423' - b'MUR'
# *Crawler filing_10K: b'0000929994' - b'ALC'
# *Crawler filing_10K: b'0000356830' - b'OSCIQ'
# *Crawler filing_10K: b'0001205727' - b'CBEY'
# *Crawler filing_10K: b'0001415020' - b'TC'
# *Crawler filing_10K: b'0000002098' - b'ACU'
# *Crawler filing_10K: b'0001024725' - b'TEN'
# *Crawler filing_10K: b'0001018946' - b'STNR'
# *Crawler filing_10K: b'0001491675' - b'CCE'
# *Crawler filing_10K: b'0001009672' - b'CRR'
# *Crawler filing_10K: b'0000893162' - b'CMOS'
# *Crawler filing_10K: b'0000915779' - b'DAKT'
# *Crawler filing_10K: b'0001362959' - b'ROSG'
# *Crawler filing_10K: b'0001329919' - b'VOCS'
# *Crawler filing_10K: b'0001285735' - b'NINE'
# *Crawler filing_10K: b'0000814549' - b'EBIX'
# *Crawler filing_10K: b'0000012659' - b'HRB'
# *Crawler filing_10K: b'0001329394' - b'SIMO'
# *Crawler filing_10K: b'0000884130' - b'CRCV'
# *Crawler filing_10K: b'0000050710' - b'JAV'
# *Crawler filing_10K: b'0001089976' - b'PTV'
# *Crawler filing_10K: b'0000792977' - b'AMAG'
# *Crawler filing_10K: b'0001359055' - b'BGH.2'
# *Crawler filing_10K: b'0001122491' - b'BRFS'
# *Crawler filing_10K: b'0000927355' - b'TESS'
# *Crawler filing_10K: b'0001077866' - b'LOOK'
# *Crawler filing_10K: b'0001061574' - b'GIB'
# *Crawler filing_10K: b'0000019446' - b'CMN'
# *Crawler filing_10K: b'0000019731' - b'CSKEQ'
# *Crawler filing_10K: b'0001108332' - b'ALVRQ'
# *Crawler filing_10K: b'0001080359' - b'ALOY'
# *Crawler filing_10K: b'0000880419' - b'OBTLY'
# *Crawler filing_10K: b'0000095521' - b'SVU'
# *Crawler filing_10K: b'0001022964' - b'CTQN'
# *Crawler filing_10K: b'0001017815' - b'QEPC'
# *Crawler filing_10K: b'0001160262' - b'MTENY'
# *Crawler filing_10K: b'0000810332' - b'MESAQ'
# *Crawler filing_10K: b'0001016152' - b'CRN'
# *Crawler filing_10K: b'0000353020' - b'AEGN'
# *Crawler filing_10K: b'0001002047' - b'NTAP'
# *Crawler filing_10K: b'0001281774' - b'CLUB'
# *Crawler filing_10K: b'0001144215' - b'AYI'
# *Crawler filing_10K: b'0000910631' - b'KOF'
# *Crawler filing_10K: b'0001357227' - b'FGXI'
# *Crawler filing_10K: b'0000105319' - b'WTW'
# *Crawler filing_10K: b'0000808326' - b'EMKR'
# *Crawler filing_10K: b'0000037785' - b'FMC'
# *Crawler filing_10K: b'0000929452' - b'KNX'
# *Crawler filing_10K: b'0001298978' - b'LEDR'
# *Crawler filing_10K: b'0001001601' - b'MGT'
# *Crawler filing_10K: b'0001093691' - b'PLUG'
# *Crawler filing_10K: b'0001333248' - b'CADX'
# *Crawler filing_10K: b'0000737572' - b'ELN'
# *Crawler filing_10K: b'0001003124' - b'PPDI'
# *Crawler filing_10K: b'0001417961' - b'VIT'
# *Crawler filing_10K: b'0000357294' - b'HOV'
# *Crawler filing_10K: b'0001140310' - b'ESNC'
# *Crawler filing_10K: b'0001371217' - b'ETRM'
# *Crawler filing_10K: b'0000906526' - b'GRDCY'
# *Crawler filing_10K: b'0001293257' - b'HTX'
# *Crawler filing_10K: b'0000016104' - b'CAGAQ'
# *Crawler filing_10K: b'0001280452' - b'MPWR'
# *Crawler filing_10K: b'0001040470' - b'AEHR'
# *Crawler filing_10K: b'0001083301' - b'IKNX'
# *Crawler filing_10K: b'0001063254' - b'SONE'
# *Crawler filing_10K: b'0000060519' - b'LPX'
# *Crawler filing_10K: b'0001332639' - b'SSW'
# *Crawler filing_10K: b'0001111759' - b'SPIL'
# *Crawler filing_10K: b'0001345564' - b'CRRRF'
# *Crawler filing_10K: b'0000097216' - b'TEX'
# *Crawler filing_10K: b'0000803016' - b'CFNB'
# *Crawler filing_10K: b'0001451505' - b'RIG'
# *Crawler filing_10K: b'0001133311' - b'TZOO'
# *Crawler filing_10K: b'0000202058' - b'HRS'
# *Crawler filing_10K: b'0000932628' - b'APU'
# *Crawler filing_10K: b'0001162556' - b'DDE'
# *Crawler filing_10K: b'0001178879' - b'FOLD'
# *Crawler filing_10K: b'0000893965' - b'TUTR'
# *Crawler filing_10K: b'0001018710' - b'INGNQ'
# *Crawler filing_10K: b'0000730000' - b'SUPX'
# *Crawler filing_10K: b'0001175580' - b'GOLD'
# *Crawler filing_10K: b'0000019871' - b'CVR'
# *Crawler filing_10K: b'0000890640' - b'CREL'
# *Crawler filing_10K: b'0001096788' - b'KNOL'
# *Crawler filing_10K: b'0001095277' - b'INTX'
# *Crawler filing_10K: b'0000108516' - b'WOR'
# *Crawler filing_10K: b'0000818686' - b'TEVA'
# *Crawler filing_10K: b'0000911971' - b'TK'
# *Crawler filing_10K: b'0001370433' - b'TIL.2'
# *Crawler filing_10K: b'0000010795' - b'BDX'
# *Crawler filing_10K: b'0000319815' - b'MXWL'
# *Crawler filing_10K: b'0000009326' - b'BCPC'
# *Crawler filing_10K: b'0001023364' - b'ABTL'
# *Crawler filing_10K: b'0000025445' - b'CR'
# *Crawler filing_10K: b'0001162192' - b'AVRX'
# *Crawler filing_10K: b'0000006284' - b'ALOG'
# *Crawler filing_10K: b'0001309799' - b'HTE'
# *Crawler filing_10K: b'0000047518' - b'HRC'
# *Crawler filing_10K: b'0001094348' - b'MATR'
# *Crawler filing_10K: b'0000842295' - b'TORM'
# *Crawler filing_10K: b'0000098677' - b'TR'
# *Crawler filing_10K: b'0000277948' - b'CSX'
# *Crawler filing_10K: b'0000039092' - b'FRD'
# *Crawler filing_10K: b'0001036188' - b'QADA'
# *Crawler filing_10K: b'0000104040' - b'WACLY'
# *Crawler filing_10K: b'0001023734' - b'BPZRQ'
# *Crawler filing_10K: b'0001158463' - b'JBLU'
# *Crawler filing_10K: b'0001297830' - b'JRJC'
# *Crawler filing_10K: b'0000027093' - b'DRAM'
# *Crawler filing_10K: b'0001060955' - b'ICLR'
# *Crawler filing_10K: b'0001375336' - b'OSBK'
# *Crawler filing_10K: b'0001271554' - b'EGI'
# *Crawler filing_10K: b'0001069394' - b'FSI'
# *Crawler filing_10K: b'0000926423' - b'MIND'
# *Crawler filing_10K: b'0000884887' - b'RCL'
# *Crawler filing_10K: b'0001009244' - b'CASA'
# *Crawler filing_10K: b'0000065201' - b'MPR'
# *Crawler filing_10K: b'0001319150' - b'PBM'
# *Crawler filing_10K: b'0000920527' - b'PSSI'
# *Crawler filing_10K: b'0000849448' - b'LIFC'
# *Crawler filing_10K: b'0001239188' - b'GSI'
# *Crawler filing_10K: b'0001277856' - b'CATM'
# *Crawler filing_10K: b'0001260221' - b'TDG'
# *Crawler filing_10K: b'0001001902' - b'IVAC'
# *Crawler filing_10K: b'0001056285' - b'KIRK'
# *Crawler filing_10K: b'0000088948' - b'SENEA'
# *Crawler filing_10K: b'0001042821' - b'PVSW'
# *Crawler filing_10K: b'0001084991' - b'NGS'
# *Crawler filing_10K: b'0000794367' - b'M'
# *Crawler filing_10K: b'0001001807' - b'TLK'
# *Crawler filing_10K: b'0001409375' - b'OESX'
# *Crawler filing_10K: b'0001294250' - b'RLOG'
# *Crawler filing_10K: b'0000931911' - b'WSTF'
# *Crawler filing_10K: b'0000049930' - b'IPII'
# *Crawler filing_10K: b'0000858803' - b'AVNR'
# *Crawler filing_10K: b'0000845072' - b'PIII'
# *Crawler filing_10K: b'0000887921' - b'REV'
# *Crawler filing_10K: b'0000790703' - b'TECD'
# *Crawler filing_10K: b'0000820738' - b'TIGR'
# *Crawler filing_10K: b'0001123494' - b'HBIO'
# *Crawler filing_10K: b'0000768408' - b'CYAN'
# *Crawler filing_10K: b'0001290900' - b'CVGI'
# *Crawler filing_10K: b'0000089261' - b'EXEX'
# *Crawler filing_10K: b'0001072343' - b'ARJ'
# *Crawler filing_10K: b'0001110646' - b'NTES'
# *Crawler filing_10K: b'0000063330' - b'MLP'
# *Crawler filing_10K: b'0001089496' - b'AIXG'
# *Crawler filing_10K: b'0000884719' - b'FCSEQ'
# *Crawler filing_10K: b'0001294538' - b'WOLF'
# *Crawler filing_10K: b'0000869561' - b'RCCC'
# *Crawler filing_10K: b'0001192305' - b'XPRT'
# *Crawler filing_10K: b'0001300578' - b'INVC'
# *Crawler filing_10K: b'0001054836' - b'FNDT'
# *Crawler filing_10K: b'0000808461' - b'GNCMA'
# *Crawler filing_10K: b'0001119639' - b'PBR'
# *Crawler filing_10K: b'0001067837' - b'ETM'
# *Crawler filing_10K: b'0000008063' - b'ATRO'
# *Crawler filing_10K: b'0001307954' - b'HUN'
# *Crawler filing_10K: b'0000883952' - b'ARA.1'
# *Crawler filing_10K: b'0001378239' - b'OMAB'
# *Crawler filing_10K: b'0000020212' - b'CHDN'
# *Crawler filing_10K: b'0001169424' - b'PSBC'
# *Crawler filing_10K: b'0000031347' - b'ELON'
# *Crawler filing_10K: b'0001062530' - b'DRIV'
# *Crawler filing_10K: b'0000022444' - b'CMC'
# *Crawler filing_10K: b'0001051009' - b'SHOEQ'
# *Crawler filing_10K: b'0001267482' - b'SMI'
# *Crawler filing_10K: b'0000849667' - b'AIPC'
# *Crawler filing_10K: b'0001001604' - b'ESC'
# *Crawler filing_10K: b'0000022252' - b'CMRO'
# *Crawler filing_10K: b'0001071321' - b'TKC'
# *Crawler filing_10K: b'0000019411' - b'MGLN'
# *Crawler filing_10K: b'0000901576' - b'REPYY'
# *Crawler filing_10K: b'0001297720' - b'JRCCQ'
# *Crawler filing_10K: b'0000216085' - b'HVT'
# *Crawler filing_10K: b'0000914025' - b'PLT'
# *Crawler filing_10K: b'0000891293' - b'CTIC'
# *Crawler filing_10K: b'0000918581' - b'CBR'
# *Crawler filing_10K: b'0001159152' - b'JHX'
# *Crawler filing_10K: b'0001011064' - b'SRZ'
# *Crawler filing_10K: b'0000912093' - b'VIAV'
# *Crawler filing_10K: b'0001376610' - b'ANVGQ'
# *Crawler filing_10K: b'0001111335' - b'VC'
# *Crawler filing_10K: b'0000050725' - b'GFF'
# *Crawler filing_10K: b'0000016099' - b'LUB'
# *Crawler filing_10K: b'0001086939' - b'NOVA'
# *Crawler filing_10K: b'0000890908' - b'DYII'
# *Crawler filing_10K: b'0001140859' - b'ABC'
# *Crawler filing_10K: b'0001378453' - b'TA'
# *Crawler filing_10K: b'0001005229' - b'CMCO'
# *Crawler filing_10K: b'0000833845' - b'WEL'
# *Crawler filing_10K: b'0000277058' - b'UWN'
# *Crawler filing_10K: b'0000310354' - b'SXI'
# *Crawler filing_10K: b'0001075880' - b'NVGN'
# *Crawler filing_10K: b'0001029142' - b'DVAX'
# *Crawler filing_10K: b'0001130166' - b'CYCC'
# *Crawler filing_10K: b'0000880266' - b'AGCO'
# *Crawler filing_10K: b'0001095315' - b'PFSW'
# *Crawler filing_10K: b'0000730349' - b'TOF'
# *Crawler filing_10K: b'0001316360' - b'IHS'
# *Crawler filing_10K: b'0001114483' - b'GB'
# *Crawler filing_10K: b'0001362988' - b'AYR'
# *Crawler filing_10K: b'0000793044' - b'CKXE'
# *Crawler filing_10K: b'0000809248' - b'TAST'
# *Crawler filing_10K: b'0000857644' - b'TPP.1'
# *Crawler filing_10K: b'0000921500' - b'CGX'
# *Crawler filing_10K: b'0000918160' - b'AKS'
# *Crawler filing_10K: b'0001337749' - b'TVH'
# *Crawler filing_10K: b'0000091142' - b'AOS'
# *Crawler filing_10K: b'0001279495' - b'BTE'
# *Crawler filing_10K: b'0001085763' - b'WVCMY'
# *Crawler filing_10K: b'0000078536' - b'DINE'
# *Crawler filing_10K: b'0001124394' - b'HYDGQ'
# *Crawler filing_10K: b'0001013857' - b'PEGA'
# *Crawler filing_10K: b'0000897893' - b'PRLS'
# *Crawler filing_10K: b'0001048268' - b'IESC'
# *Crawler filing_10K: b'0001072379' - b'NWBO'
# *Crawler filing_10K: b'0000006955' - b'ATU'
# *Crawler filing_10K: b'0000006814' - b'CFS'
# *Crawler filing_10K: b'0001090069' - b'CHRK'
# *Crawler filing_10K: b'0000096699' - b'TCCO'
# *Crawler filing_10K: b'0001042185' - b'VIGN'
# *Crawler filing_10K: b'0000874710' - b'AHPI'
# *Crawler filing_10K: b'0000918965' - b'SCSC'
# *Crawler filing_10K: b'0000903129' - b'THRM'
# *Crawler filing_10K: b'0001281696' - b'BJGP'
# *Crawler filing_10K: b'0000917520' - b'IART'
# *Crawler filing_10K: b'0001361983' - b'ORBC'
# *Crawler filing_10K: b'0001396009' - b'VMC'
# *Crawler filing_10K: b'0000784011' - b'POPE'
# *Crawler filing_10K: b'0001171032' - b'BKRSQ'
# *Crawler filing_10K: b'0001019695' - b'ARQL'
# *Crawler filing_10K: b'0001030653' - b'CRGN'
# *Crawler filing_10K: b'0001379895' - b'DYN'
# *Crawler filing_10K: b'0001048286' - b'MAR'
# *Crawler filing_10K: b'0000943184' - b'EVK'
# *Crawler filing_10K: b'0000724742' - b'TPHS'
# *Crawler filing_10K: b'0000722104' - b'SVNTQ'
# *Crawler filing_10K: b'0001116755' - b'DWRI'
# *Crawler filing_10K: b'0000037996' - b'F'
# *Crawler filing_10K: b'0000816956' - b'CNMD'
# *Crawler filing_10K: b'0001001193' - b'TMTA'
# *Crawler filing_10K: b'0001168195' - b'FIRE'
# *Crawler filing_10K: b'0001002037' - b'LTRE'
# *Crawler filing_10K: b'0000946815' - b'LTEC'
# *Crawler filing_10K: b'0001138951' - b'LF'
# *Crawler filing_10K: b'0000069671' - b'NAFC'
# *Crawler filing_10K: b'0000849213' - b'PCL'
# *Crawler filing_10K: b'0000855931' - b'POT'
# *Crawler filing_10K: b'0000892907' - b'SPCHA'
# *Crawler filing_10K: b'0000906779' - b'GCSAY'
# *Crawler filing_10K: b'0001040593' - b'CRZO'
# *Crawler filing_10K: b'0001073429' - b'USCR'
# *Crawler filing_10K: b'0000880224' - b'ITPOF'
# *Crawler filing_10K: b'0001323531' - b'MFB'
# *Crawler filing_10K: b'0001103982' - b'MDLZ'
# *Crawler filing_10K: b'0001131554' - b'SNCR'
# *Crawler filing_10K: b'0000840467' - b'BEC'
# *Crawler filing_10K: b'0001076195' - b'LTM'
# *Crawler filing_10K: b'0000885307' - b'JCTCF'
# *Crawler filing_10K: b'0001335258' - b'LYV'
# *Crawler filing_10K: b'0000035214' - b'FOE'
# *Crawler filing_10K: b'0001565025' - b'ABEV'
# *Crawler filing_10K: b'0000944480' - b'GVP'
# *Crawler filing_10K: b'0000845802' - b'DRAX'
# *Crawler filing_10K: b'0001402305' - b'SFSF'
# *Crawler filing_10K: b'0000868725' - b'RTK'
# *Crawler filing_10K: b'0001161154' - b'SXL'
# *Crawler filing_10K: b'0000769594' - b'NTT'
# *Crawler filing_10K: b'0001117119' - b'KNTA'
# *Crawler filing_10K: b'0000943819' - b'RMD'
# *Crawler filing_10K: b'0001035983' - b'FIX'
# *Crawler filing_10K: b'0000742112' - b'IVC'
# *Crawler filing_10K: b'0001333172' - b'NM'
# *Crawler filing_10K: b'0001430725' - b'GSL'
# *Crawler filing_10K: b'0000892025' - b'MATK'
# *Crawler filing_10K: b'0001094392' - b'RTEC'
# *Crawler filing_10K: b'0001129155' - b'MPX'
# *Crawler filing_10K: b'0000842633' - b'TRS'
# *Crawler filing_10K: b'0001011344' - b'PKTR'
# *Crawler filing_10K: b'0000088121' - b'SEB'
# *Crawler filing_10K: b'0000314606' - b'GEOKQ'
# *Crawler filing_10K: b'0000917523' - b'RVLT'
# *Crawler filing_10K: b'0000835768' - b'MAIR'
# *Crawler filing_10K: b'0001083522' - b'JSDA'
# *Crawler filing_10K: b'0001001316' - b'TGTX'
# *Crawler filing_10K: b'0001311967' - b'SMC.2'
# *Crawler filing_10K: b'0001135152' - b'FTI'
# *Crawler filing_10K: b'0000912241' - b'PGICQ'
# *Crawler filing_10K: b'0001322866' - b'KOG'
# *Crawler filing_10K: b'0001158833' - b'LSR'
# *Crawler filing_10K: b'0001157601' - b'SNTA'
# *Crawler filing_10K: b'0000032621' - b'MSN'
# *Crawler filing_10K: b'0000883943' - b'CBK'
# *Crawler filing_10K: b'0001292556' - b'PPO'
# *Crawler filing_10K: b'0001043914' - b'ORXE'
# *Crawler filing_10K: b'0001122787' - b'NAPS'
# *Crawler filing_10K: b'0001323404' - b'SLW'
# *Crawler filing_10K: b'0000725363' - b'CVM'
# *Crawler filing_10K: b'0001090908' - b'DTRM'
# *Crawler filing_10K: b'0000033002' - b'EBF'
# *Crawler filing_10K: b'0001049521' - b'MRCY'
# *Crawler filing_10K: b'0001287950' - b'SPRD'
# *Crawler filing_10K: b'0000872248' - b'PQ'
# *Crawler filing_10K: b'0000936395' - b'CIEN'
# *Crawler filing_10K: b'0000275053' - b'NATR'
# *Crawler filing_10K: b'0000014272' - b'BMY'
# *Crawler filing_10K: b'0000771266' - b'KOPN'
# *Crawler filing_10K: b'0001275229' - b'GMO'
# *Crawler filing_10K: b'0000887936' - b'FCN'
# *Crawler filing_10K: b'0001313024' - b'VQ'
# *Crawler filing_10K: b'0000838879' - b'RXPC'
# *Crawler filing_10K: b'0001173382' - b'CAE'
# *Crawler filing_10K: b'0001114872' - b'MCELQ'
# *Crawler filing_10K: b'0001043277' - b'CHRW'
# *Crawler filing_10K: b'0001175636' - b'EEEI'
# *Crawler filing_10K: b'0001002637' - b'MLNM'
# *Crawler filing_10K: b'0001369241' - b'DAC'
# *Crawler filing_10K: b'0000805054' - b'TEAM'
# *Crawler filing_10K: b'0000721083' - b'SII'
# *Crawler filing_10K: b'0001008654' - b'TUP'
# *Crawler filing_10K: b'0000055785' - b'KMB'
# *Crawler filing_10K: b'0001215546' - b'OZN'
# *Crawler filing_10K: b'0000849502' - b'RMTR'
# *Crawler filing_10K: b'0001019439' - b'WALK'
# *Crawler filing_10K: b'0000038570' - b'OHBIQ'
# *Crawler filing_10K: b'0000817720' - b'SYNA'
# *Crawler filing_10K: b'0000868278' - b'PRPH'
# *Crawler filing_10K: b'0000792987' - b'ASTE'
# *Crawler filing_10K: b'0000865492' - b'GBGLF'
# *Crawler filing_10K: b'0001094007' - b'VCTL'
# *Crawler filing_10K: b'0000919794' - b'ENLV'
# *Crawler filing_10K: b'0001342575' - b'SCOP'
# *Crawler filing_10K: b'0000914475' - b'NBIX'
# *Crawler filing_10K: b'0000715073' - b'WGNR'
# *Crawler filing_10K: b'0001031029' - b'SRT'
# *Crawler filing_10K: b'0000904979' - b'SHLO'
# *Crawler filing_10K: b'0000907649' - b'FXEN'
# *Crawler filing_10K: b'0001000180' - b'SNDK'
# *Crawler filing_10K: b'0000902791' - b'BBSI'
# *Crawler filing_10K: b'0001347178' - b'VNDA'
# *Crawler filing_10K: b'0000901832' - b'AZN'
# *Crawler filing_10K: b'0000080424' - b'PG'
# *Crawler filing_10K: b'0000935226' - b'BNHN'
# *Crawler filing_10K: b'0000050104' - b'TSO'
# *Crawler filing_10K: b'0001345111' - b'THI'
# *Crawler filing_10K: b'0001039399' - b'FORM'
# *Crawler filing_10K: b'0000885725' - b'BSX'
# *Crawler filing_10K: b'0000723371' - b'HTMXQ'
# *Crawler filing_10K: b'0001307752' - b'VSCP'
# *Crawler filing_10K: b'0000701818' - b'KGC'
# *Crawler filing_10K: b'0000007431' - b'AWI'
# *Crawler filing_10K: b'0000909793' - b'NETM'
# *Crawler filing_10K: b'0000811532' - b'FUN'
# *Crawler filing_10K: b'0001037646' - b'MTD'
# *Crawler filing_10K: b'0001157758' - b'ATCV'
# *Crawler filing_10K: b'0001030475' - b'CEA'
# *Crawler filing_10K: b'0001282637' - b'NEU'
# *Crawler filing_10K: b'0000108601' - b'WWY'
# *Crawler filing_10K: b'0000912562' - b'ROCK'
# *Crawler filing_10K: b'0001061219' - b'EPD'
# *Crawler filing_10K: b'0001012019' - b'RUSHA'
# *Crawler filing_10K: b'0001105472' - b'SONS'
# *Crawler filing_10K: b'0001021561' - b'NUS'
# *Crawler filing_10K: b'0000820736' - b'ORB'
# *Crawler filing_10K: b'0000895419' - b'CREE'
# *Crawler filing_10K: b'0001005201' - b'DEPO'
# *Crawler filing_10K: b'0000032166' - b'ELRC'
# *Crawler filing_10K: b'0000350698' - b'AN'
# *Crawler filing_10K: b'0000004187' - b'IDSA'
# *Crawler filing_10K: b'0000946840' - b'VPHM'
# *Crawler filing_10K: b'0001040130' - b'PETS'
# *Crawler filing_10K: b'0000003116' - b'AKRX'
# *Crawler filing_10K: b'0000849547' - b'BBOX'
# *Crawler filing_10K: b'0001386198' - b'MEMS'
# *Crawler filing_10K: b'0000874292' - b'AEY'
# *Crawler filing_10K: b'0001050031' - b'WINS'
# *Crawler filing_10K: b'0000030305' - b'DCO'
# *Crawler filing_10K: b'0000039273' - b'FFEX'
# *Crawler filing_10K: b'0000039047' - b'FRS'
# *Crawler filing_10K: b'0001214299' - b'TLKGY'
# *Crawler filing_10K: b'0001059784' - b'GNBT'
# *Crawler filing_10K: b'0001161963' - b'AMIS'
# *Crawler filing_10K: b'0000919013' - b'WAVX'
# *Crawler filing_10K: b'0001391390' - b'BZ'
# *Crawler filing_10K: b'0001262976' - b'CMPR'
# *Crawler filing_10K: b'0001145124' - b'SWIM'
# *Crawler filing_10K: b'0000800240' - b'ODP'
# *Crawler filing_10K: b'0000895447' - b'SCVL'
# *Crawler filing_10K: b'0001070494' - b'ACAD'
# *Crawler filing_10K: b'0000849240' - b'HWK'
# *Crawler filing_10K: b'0001006269' - b'LORL'
# *Crawler filing_10K: b'0001351548' - b'FRNTQ'
# *Crawler filing_10K: b'0000834365' - b'BLFS'
# *Crawler filing_10K: b'0001069878' - b'TREX'
# *Crawler filing_10K: b'0001065049' - b'LEAP'
# *Crawler filing_10K: b'0000880115' - b'CWEI'
# *Crawler filing_10K: b'0000700721' - b'AMAC'
# *Crawler filing_10K: b'0001036848' - b'ACY'
# *Crawler filing_10K: b'0001086600' - b'ARLP'
# *Crawler filing_10K: b'0001097264' - b'ALTH'
# *Crawler filing_10K: b'0000846913' - b'FTEK'
# *Crawler filing_10K: b'0001235468' - b'LQDT'
# *Crawler filing_10K: b'0001130258' - b'APKT'
# *Crawler filing_10K: b'0000913077' - b'AFFX'
# *Crawler filing_10K: b'0000800460' - b'CAMD'
# *Crawler filing_10K: b'0001117171' - b'CBAK'
# *Crawler filing_10K: b'0001085280' - b'TIBX'
# *Crawler filing_10K: b'0001092367' - b'SCMR'
# *Crawler filing_10K: b'0001333849' - b'JAGGF'
# *Crawler filing_10K: b'0000732026' - b'TRT'
# *Crawler filing_10K: b'0001057997' - b'ARMH'
# *Crawler filing_10K: b'0001230992' - b'MVG'
# *Crawler filing_10K: b'0000069633' - b'NSSC'
# *Crawler filing_10K: b'0000720851' - b'NEST'
# *Crawler filing_10K: b'0001104730' - b'VYYO'
# *Crawler filing_10K: b'0001268904' - b'ETWC'
# *Crawler filing_10K: b'0000870228' - b'SYBRQ'
# *Crawler filing_10K: b'0001093885' - b'SNWL'
# *Crawler filing_10K: b'0001344632' - b'LWSN'
# *Crawler filing_10K: b'0000056868' - b'PNRG'
# *Crawler filing_10K: b'0001166036' - b'MWE'
# *Crawler filing_10K: b'0001363381' - b'HPGP'
# *Crawler filing_10K: b'0001203748' - b'GNA'
# *Crawler filing_10K: b'0001016504' - b'INBP'
# *Crawler filing_10K: b'0001375063' - b'SYMX'
# *Crawler filing_10K: b'0000788920' - b'PDEX'
# *Crawler filing_10K: b'0000924646' - b'MPS'
# *Crawler filing_10K: b'0001058033' - b'NWA'
# *Crawler filing_10K: b'0000896985' - b'DEST'
# *Crawler filing_10K: b'0001306527' - b'HLND'
# *Crawler filing_10K: b'0000907654' - b'ABIO'
# *Crawler filing_10K: b'0000857005' - b'PTC'
# *Crawler filing_10K: b'0001316625' - b'SGI'
# *Crawler filing_10K: b'0000869487' - b'TBACQ'
# *Crawler filing_10K: b'0000776325' - b'RSCR'
# *Crawler filing_10K: b'0001047699' - b'KG'
# *Crawler filing_10K: b'0000812011' - b'MTN'
# *Crawler filing_10K: b'0001043156' - b'STRZ'
# *Crawler filing_10K: b'0001040570' - b'GEOY'
# *Crawler filing_10K: b'0001100412' - b'ARRY'
# *Crawler filing_10K: b'0001315257' - b'KOP'
# *Crawler filing_10K: b'0000867773' - b'SPWR'
# *Crawler filing_10K: b'0001002135' - b'WSTL'
# *Crawler filing_10K: b'0000085704' - b'HTSI'
# *Crawler filing_10K: b'0000842162' - b'LEA'
# *Crawler filing_10K: b'0001133519' - b'MCUJF'
# *Crawler filing_10K: b'0001084201' - b'SVA'
# *Crawler filing_10K: b'0000833640' - b'POWI'
# *Crawler filing_10K: b'0001301611' - b'LPNT'
# *Crawler filing_10K: b'0001065246' - b'HIFN'
# *Crawler filing_10K: b'0001172139' - b'BBG'
# *Crawler filing_10K: b'0000922960' - b'NCX'
# *Crawler filing_10K: b'0001091735' - b'PACR'
# *Crawler filing_10K: b'0000805326' - b'EMIS'
# *Crawler filing_10K: b'0000060876' - b'CYBI'
# *Crawler filing_10K: b'0000864839' - b'ROYL'
# *Crawler filing_10K: b'0001286597' - b'BAA'
# *Crawler filing_10K: b'0000778164' - b'PEIX'
# *Crawler filing_10K: b'0001132924' - b'CHT'
# *Crawler filing_10K: b'0001415404' - b'SATS'
# *Crawler filing_10K: b'0000002809' - b'AEM'
# *Crawler filing_10K: b'0000739608' - b'PENX'
# *Crawler filing_10K: b'0000928465' - b'DIT'
# *Crawler filing_10K: b'0001009829' - b'JAKK'
# *Crawler filing_10K: b'0000109156' - b'ZLC'
# *Crawler filing_10K: b'0000909724' - b'TLF'
# *Crawler filing_10K: b'0000039677' - b'AVHI'
# *Crawler filing_10K: b'0001170650' - b'MHS'
# *Crawler filing_10K: b'0001003022' - b'ZRAN'
# *Crawler filing_10K: b'0000094610' - b'SSCC'
# *Crawler filing_10K: b'0000885978' - b'USPH'
# *Crawler filing_10K: b'0001071625' - b'DOVR'
# *Crawler filing_10K: b'0001297024' - b'ORSX'
# *Crawler filing_10K: b'0000915324' - b'WRLS'
# *Crawler filing_10K: b'0000109758' - b'ARB'
# *Crawler filing_10K: b'0000802100' - b'VELCF'
# *Crawler filing_10K: b'0000099302' - b'TRNS'
# *Crawler filing_10K: b'0001065059' - b'LEU'
# *Crawler filing_10K: b'0001162324' - b'URZ'
# *Crawler filing_10K: b'0001005504' - b'WIRX'
# *Crawler filing_10K: b'0001264089' - b'AUY'
# *Crawler filing_10K: b'0000918027' - b'HSR.1'
# *Crawler filing_10K: b'0001162315' - b'EPAX'
# *Crawler filing_10K: b'0001356949' - b'HWCC'
# *Crawler filing_10K: b'0001126741' - b'GSIT'
# *Crawler filing_10K: b'0001386607' - b'QXMCF'
# *Crawler filing_10K: b'0000009342' - b'BEZ'
# *Crawler filing_10K: b'0001015577' - b'CNET.'
# *Crawler filing_10K: b'0001388430' - b'CAI'
# *Crawler filing_10K: b'0000948634' - b'CXP.1'
# *Crawler filing_10K: b'0001028584' - b'AMCS'
# *Crawler filing_10K: b'0001095600' - b'BCSI'
# *Crawler filing_10K: b'0001398090' - b'PMII'
# *Crawler filing_10K: b'0000746598' - b'BRC'
# *Crawler filing_10K: b'0001415016' - b'GA'
# *Crawler filing_10K: b'0001164727' - b'NEM'
# *Crawler filing_10K: b'0000883979' - b'PMRY'
# *Crawler filing_10K: b'0001265888' - b'NSR'
# *Crawler filing_10K: b'0000896778' - b'CPTS'
# *Crawler filing_10K: b'0000845982' - b'SNN'
# *Crawler filing_10K: b'0001392972' - b'PRO'
# *Crawler filing_10K: b'0001084876' - b'RAE'
# *Crawler filing_10K: b'0001339947' - b'VIAB'
# *Crawler filing_10K: b'0000053669' - b'JCI'
# *Crawler filing_10K: b'0000101984' - b'UEIC'
# *Crawler filing_10K: b'0000877357' - b'SEPR'
# *Crawler filing_10K: b'0000912061' - b'NHTC'
# *Crawler filing_10K: b'0000945828' - b'AMTY'
# *Crawler filing_10K: b'0000728303' - b'CRV'
# *Crawler filing_10K: b'0000879575' - b'TNH'
# *Crawler filing_10K: b'0000310158' - b'MRK'
# *Crawler filing_10K: b'0000056701' - b'KOSS'
# *Crawler filing_10K: b'0001037038' - b'RL'
# *Crawler filing_10K: b'0000935494' - b'NATI'
# *Crawler filing_10K: b'0001014041' - b'STRC'
# *Crawler filing_10K: b'0001391984' - b'DDUP'
# *Crawler filing_10K: b'0001361937' - b'EVEP'
# *Crawler filing_10K: b'0001298341' - b'NLC'
# *Crawler filing_10K: b'0001000228' - b'HSIC'
# *Crawler filing_10K: b'0000813920' - b'CEC'
# *Crawler filing_10K: b'0000861838' - b'IDRA'
# *Crawler filing_10K: b'0001013934' - b'STRA'
# *Crawler filing_10K: b'0000320186' - b'GW'
# *Crawler filing_10K: b'0001102993' - b'LPSN'
# *Crawler filing_10K: b'0000914398' - b'ESYS'
# *Crawler filing_10K: b'0001034670' - b'ALV'
# *Crawler filing_10K: b'0000091767' - b'SON'
# *Crawler filing_10K: b'0001084577' - b'CYRN'
# *Crawler filing_10K: b'0001316898' - b'JMBA'
# *Crawler filing_10K: b'0001016281' - b'CSV'
# *Crawler filing_10K: b'0001045986' - b'FORTY'
# *Crawler filing_10K: b'0000320340' - b'INS'
# *Crawler filing_10K: b'0001057791' - b'RBY'
# *Crawler filing_10K: b'0001001115' - b'GEOS'
# *Crawler filing_10K: b'0001210708' - b'HSON'
# *Crawler filing_10K: b'0001034760' - b'WYY'
# *Crawler filing_10K: b'0000835011' - b'MGPI'
# *Crawler filing_10K: b'0000886530' - b'DTRK'
# *Crawler filing_10K: b'0001092839' - b'DUNRQ'
# *Crawler filing_10K: b'0000055772' - b'KBAL'
# *Crawler filing_10K: b'0001167419' - b'APPY'
# *Crawler filing_10K: b'0000906282' - b'MTMC'
# *Crawler filing_10K: b'0000887153' - b'SIM'
# *Crawler filing_10K: b'0001344154' - b'EMS'
# *Crawler filing_10K: b'0000899723' - b'OMG'
# *Crawler filing_10K: b'0001094316' - b'TTPA'
# *Crawler filing_10K: b'0000913290' - b'FRO'
# *Crawler filing_10K: b'0000060751' - b'LZ'
# *Crawler filing_10K: b'0000043300' - b'GAPTQ'
# *Crawler filing_10K: b'0001085482' - b'TWB'
# *Crawler filing_10K: b'0001001868' - b'FTGX'
# *Crawler filing_10K: b'0000811240' - b'BIOL'
# *Crawler filing_10K: b'0001271129' - b'FRG'
# *Crawler filing_10K: b'0000888504' - b'LAYN'
# *Crawler filing_10K: b'0001130626' - b'LDIS'
# *Crawler filing_10K: b'0001042134' - b'CHRD'
# *Crawler filing_10K: b'0000316300' - b'XCO'
# *Crawler filing_10K: b'0001120295' - b'XXIA'
# *Crawler filing_10K: b'0000071478' - b'LIPD'
# *Crawler filing_10K: b'0001093082' - b'HBP'
# *Crawler filing_10K: b'0001275011' - b'VRXMF'
# *Crawler filing_10K: b'0001342958' - b'DGLY'
# *Crawler filing_10K: b'0000925645' - b'CETV'
# *Crawler filing_10K: b'0000885639' - b'KSS'
# *Crawler filing_10K: b'0000933036' - b'RCII'
# *Crawler filing_10K: b'0001383650' - b'CQP'
# *Crawler filing_10K: b'0001041859' - b'PLCE'
# *Crawler filing_10K: b'0000876167' - b'PRGS'
# *Crawler filing_10K: b'0000913756' - b'VITA.1'
# *Crawler filing_10K: b'0001357459' - b'CUR'
# *Crawler filing_10K: b'0001381526' - b'BUS'
# *Crawler filing_10K: b'0001362719' - b'SSBXQ'
# *Crawler filing_10K: b'0000874733' - b'MEDW'
# *Crawler filing_10K: b'0000854860' - b'WMCO'
# *Crawler filing_10K: b'0000930309' - b'DEG'
# *Crawler filing_10K: b'0000081362' - b'KWR'
# *Crawler filing_10K: b'0000318833' - b'TISI'
# *Crawler filing_10K: b'0001110206' - b'KOSN'
# *Crawler filing_10K: b'0000065358' - b'UCAP'
# *Crawler filing_10K: b'0001355855' - b'NFSB'
# *Crawler filing_10K: b'0001088825' - b'TIVO'
# *Crawler filing_10K: b'0001055355' - b'SONO'
# *Crawler filing_10K: b'0000813298' - b'DXLG'
# *Crawler filing_10K: b'0000919722' - b'ASTX'
# *Crawler filing_10K: b'0000864233' - b'CHUX'
# *Crawler filing_10K: b'0000320174' - b'PRSN'
# *Crawler filing_10K: b'0001054070' - b'NPLA'
# *Crawler filing_10K: b'0001356570' - b'WNS'
# *Crawler filing_10K: b'0000056679' - b'KFY'
# *Crawler filing_10K: b'0001077370' - b'PRZM'
# *Crawler filing_10K: b'0000841692' - b'FSII'
# *Crawler filing_10K: b'0000073773' - b'OICO'
# *Crawler filing_10K: b'0001073349' - b'EPAY'
# *Crawler filing_10K: b'0001135951' - b'RDY'
# *Crawler filing_10K: b'0000892222' - b'BREW'
# *Crawler filing_10K: b'0001053947' - b'GMKYY'
# *Crawler filing_10K: b'0001109345' - b'NVMI'
# *Crawler filing_10K: b'0000896878' - b'INTU'
# *Crawler filing_10K: b'0001047202' - b'GYI'
# *Crawler filing_10K: b'0001029145' - b'GOGL'
# *Crawler filing_10K: b'0001018833' - b'QDHC'
# *Crawler filing_10K: b'0001289340' - b'STXS'
# *Crawler filing_10K: b'0001309710' - b'ZVUE'
# *Crawler filing_10K: b'0001056794' - b'AVNX'
# *Crawler filing_10K: b'0000702165' - b'NSC'
# *Crawler filing_10K: b'0001296774' - b'NCTY'
# *Crawler filing_10K: b'0001157762' - b'CAAS'
# *Crawler filing_10K: b'0000744473' - b'CDSCY'
# *Crawler filing_10K: b'0000894627' - b'EGY'
# *Crawler filing_10K: b'0000313838' - b'SNE'
# *Crawler filing_10K: b'0000789933' - b'NC'
# *Crawler filing_10K: b'0001096481' - b'ANPMF'
# *Crawler filing_10K: b'0001119985' - b'HYGS'
# *Crawler filing_10K: b'0001409134' - b'OSP'
# *Crawler filing_10K: b'0000880807' - b'AMSC'
# *Crawler filing_10K: b'0001065280' - b'NFLX'
# *Crawler filing_10K: b'0000032604' - b'EMR'
# *Crawler filing_10K: b'0000910329' - b'MED'
# *Crawler filing_10K: b'0001071941' - b'KADR'
# *Crawler filing_10K: b'0001105841' - b'CKSW'
# *Crawler filing_10K: b'0000914242' - b'TAR'
# *Crawler filing_10K: b'0001102384' - b'ASTTY'
# *Crawler filing_10K: b'0000050957' - b'FBNIQ'
# *Crawler filing_10K: b'0000941685' - b'IWSY'
# *Crawler filing_10K: b'0000813672' - b'CDNS'
# *Crawler filing_10K: b'0000946936' - b'DSWL'
# *Crawler filing_10K: b'0001027884' - b'CBI'
# *Crawler filing_10K: b'0000866028' - b'PLM'
# *Crawler filing_10K: b'0000896493' - b'DPW'
# *Crawler filing_10K: b'0001263074' - b'PRPX'
# *Crawler filing_10K: b'0000874841' - b'PSUN'
# *Crawler filing_10K: b'0001017480' - b'HIBB'
# *Crawler filing_10K: b'0000355811' - b'GNTX'
# *Crawler filing_10K: b'0001001606' - b'BLT'
# *Crawler filing_10K: b'0001354513' - b'CTCM'
# *Crawler filing_10K: b'0001338749' - b'PCH'
# *Crawler filing_10K: b'0001037868' - b'AME'
# *Crawler filing_10K: b'0000748592' - b'NTN'
# *Crawler filing_10K: b'0001366578' - b'NTQ'
# *Crawler filing_10K: b'0000704328' - b'SMTS'
# *Crawler filing_10K: b'0001100868' - b'CJREF'
# *Crawler filing_10K: b'0000913032' - b'PSTA'
# *Crawler filing_10K: b'0000043920' - b'GEF'
# *Crawler filing_10K: b'0000030828' - b'COBR'
# *Crawler filing_10K: b'0001344596' - b'ARII'
# ...
# *Crawler filing_10K: b'0001037649' - b'ILIU'
# *Crawler filing_10K: b'0001098277' - b'WBSN'
# *Crawler filing_10K: b'0000748270' - b'MDCI'
# *Crawler filing_10K: b'0000752789' - b'XCRP'
# *Crawler filing_10K: b'0000793279' - b'CLZR'
# *Crawler filing_10K: b'0001079028' - b'VARI'
# *Crawler filing_10K: b'0000101063' - b'CQB'
# *Crawler filing_10K: b'0000278041' - b'ISH'
# *Crawler filing_10K: b'0001000753' - b'NSP'
# *Crawler filing_10K: b'0000817979' - b'ACW'
# *Crawler filing_10K: b'0001024022' - b'MSII'
# *Crawler filing_10K: b'0001089063' - b'DKS'
# *Crawler filing_10K: b'0000933157' - b'AOGSQ'
# *Crawler filing_10K: b'0000921691' - b'KCP'
# *Crawler filing_10K: b'0001022652' - b'MIFI'
# *Crawler filing_10K: b'0000924940' - b'DTPI'
# *Crawler filing_10K: b'0000783412' - b'DJCO'
# *Crawler filing_10K: b'0000819689' - b'HRT'
# *Crawler filing_10K: b'0000077877' - b'PDCE'
# *Crawler filing_10K: b'0001133872' - b'ZANE'
# *Crawler filing_10K: b'0000085961' - b'R'
# *Crawler filing_10K: b'0001059556' - b'MCO'
# *Crawler filing_10K: b'0001415921' - b'NMM'
# *Crawler filing_10K: b'0000921738' - b'PENN'
# *Crawler filing_10K: b'0000866787' - b'AZO'
# *Crawler filing_10K: b'0001099590' - b'MELI'
# *Crawler filing_10K: b'0000937556' - b'MASI'
# *Crawler filing_10K: b'0001382696' - b'FUQI'
# *Crawler filing_10K: b'0001015650' - b'SKM'
# *Crawler filing_10K: b'0001407298' - b'FLY'
# *Crawler filing_10K: b'0001035815' - b'JRCOQ'
# *Crawler filing_10K: b'0000760326' - b'OUTD'
# *Crawler filing_10K: b'0000730263' - b'THO'
# *Crawler filing_10K: b'0000099106' - b'TNLX'
# *Crawler filing_10K: b'0001370946' - b'OC'
# *Crawler filing_10K: b'0000105770' - b'WST'
# *Crawler filing_10K: b'0001069183' - b'TASR'
# *Crawler filing_10K: b'0000726514' - b'ESIO'
# *Crawler filing_10K: b'0000789868' - b'ADY'
# *Crawler filing_10K: b'0001094961' - b'MGRM'
# *Crawler filing_10K: b'0000354950' - b'HD'
# *Crawler filing_10K: b'0000717954' - b'UNF'
# *Crawler filing_10K: b'0001308161' - b'FOXA'
# *Crawler filing_10K: b'0000106535' - b'WY'
# *Crawler filing_10K: b'0001114448' - b'NVS'
# *Crawler filing_10K: b'0000010081' - b'BRL'
# *Crawler filing_10K: b'0001053221' - b'MBRX'
# *Crawler filing_10K: b'0000937941' - b'PCMI'
# *Crawler filing_10K: b'0001223389' - b'CONN'
# *Crawler filing_10K: b'0001133478' - b'IMOS'
# *Crawler filing_10K: b'0000051434' - b'IP'
# *Crawler filing_10K: b'0000949876' - b'NASMQ'
# *Crawler filing_10K: b'0001039151' - b'KNDL'
# *Crawler filing_10K: b'0001331301' - b'BDBD'
# *Crawler filing_10K: b'0000913665' - b'TSTRQ'
# *Crawler filing_10K: b'0000790526' - b'RDNT'
# *Crawler filing_10K: b'0000037748' - b'MEE'
# *Crawler filing_10K: b'0000039648' - b'GK'
# *Crawler filing_10K: b'0001005284' - b'OLED'
# *Crawler filing_10K: b'0001107194' - b'CTLM'
# *Crawler filing_10K: b'0001299969' - b'CHCI'
# *Crawler filing_10K: b'0000040211' - b'GMT'
# *Crawler filing_10K: b'0000849395' - b'CRH'
# *Crawler filing_10K: b'0000054480' - b'KSU'
# *Crawler filing_10K: b'0000932787' - b'STM'
# *Crawler filing_10K: b'0000104987' - b'ZRBA'
# *Crawler filing_10K: b'0001306830' - b'CE'
# *Crawler filing_10K: b'0001007330' - b'PRGX'
# *Crawler filing_10K: b'0001076770' - b'CDCAQ'
# *Crawler filing_10K: b'0001409171' - b'TITN'
# *Crawler filing_10K: b'0001041577' - b'ATMI'
# *Crawler filing_10K: b'0001160308' - b'MSTX'
# *Crawler filing_10K: b'0001350620' - b'REST'
# *Crawler filing_10K: b'0000023666' - b'HSH'
# *Crawler filing_10K: b'0000072333' - b'JWN'
# *Crawler filing_10K: b'0001121225' - b'BUF'
# *Crawler filing_10K: b'0001260625' - b'CSR'
# *Crawler filing_10K: b'0000716643' - b'RGS'
# *Crawler filing_10K: b'0001032975' - b'LOGI'
# *Crawler filing_10K: b'0000798287' - b'PTSI'
# *Crawler filing_10K: b'0000095304' - b'SUN.1'
# *Crawler filing_10K: b'0001326200' - b'GNK'
# *Crawler filing_10K: b'0000840216' - b'CALCQ'
# *Crawler filing_10K: b'0000864559' - b'CSCD'
# *Crawler filing_10K: b'0000890491' - b'BKS'
# *Crawler filing_10K: b'0001158324' - b'CCOI'
# *Crawler filing_10K: b'0000031235' - b'KODK'
# *Crawler filing_10K: b'0001356462' - b'YTEC'
# *Crawler filing_10K: b'0000880117' - b'JBSS'
# *Crawler filing_10K: b'0000719733' - b'KTCC'
# *Crawler filing_10K: b'0000717826' - b'ERIC'
# *Crawler filing_10K: b'0000764180' - b'MO'
# *Crawler filing_10K: b'0000873303' - b'SRPT'
# *Crawler filing_10K: b'0001119774' - b'CGEN'
# *Crawler filing_10K: b'0001413159' - b'TGH'
# *Crawler filing_10K: b'0001110452' - b'AFLYY'
# *Crawler filing_10K: b'0000806968' - b'WPPGY'
# *Crawler filing_10K: b'0000900708' - b'BELM'
# *Crawler filing_10K: b'0000934936' - b'SCLR'
# *Crawler filing_10K: b'0000101829' - b'UTX'
# *Crawler filing_10K: b'0001413745' - b'AMCN'
# *Crawler filing_10K: b'0000866273' - b'MTRX'
# *Crawler filing_10K: b'0000783324' - b'VGZ'
# *Crawler filing_10K: b'0001164863' - b'NPO'
# *Crawler filing_10K: b'0000764762' - b'LDG'
# *Crawler filing_10K: b'0000034067' - b'BOOM'
# *Crawler filing_10K: b'0000029905' - b'DOV'
# *Crawler filing_10K: b'0000020232' - b'CHYR'
# *Crawler filing_10K: b'0000722723' - b'HGR'
# *Crawler filing_10K: b'0000891178' - b'EPIC'
# *Crawler filing_10K: b'0000028823' - b'DBD'
# *Crawler filing_10K: b'0001485527' - b'COBK'
# *Crawler filing_10K: b'0000832428' - b'SSP'
# *Crawler filing_10K: b'0000007084' - b'ADM'
# *Crawler filing_10K: b'0000886128' - b'FCEL'
# *Crawler filing_10K: b'0001051846' - b'XINGF'
# *Crawler filing_10K: b'0001095747' - b'JCDAF'
# *Crawler filing_10K: b'0000822663' - b'IPAR'
# *Crawler filing_10K: b'0001023860' - b'SSFN'
# *Crawler filing_10K: b'0001399067' - b'CCME'
# *Crawler filing_10K: b'0001593034' - b'ENDP'
# *Crawler filing_10K: b'0000882873' - b'ULGX'
# *Crawler filing_10K: b'0001374535' - b'AIMC'
# *Crawler filing_10K: b'0000729156' - b'PEDH'
# *Crawler filing_10K: b'0000827809' - b'QLTI'
# *Crawler filing_10K: b'0001086222' - b'AKAM'
# *Crawler filing_10K: b'0000048039' - b'HFC'
# *Crawler filing_10K: b'0001373060' - b'MR'
# *Crawler filing_10K: b'0001126975' - b'MMP'
# *Crawler filing_10K: b'0000896726' - b'GGLR'
# *Crawler filing_10K: b'0001378789' - b'AER'
# *Crawler filing_10K: b'0000725058' - b'CYTO'
# *Crawler filing_10K: b'0000917225' - b'XPL'
# *Crawler filing_10K: b'0000884144' - b'ASUR'
# *Crawler filing_10K: b'0000719164' - b'SGK'
# *Crawler filing_10K: b'0001058090' - b'CMG'
# *Crawler filing_10K: b'0000900349' - b'PERY'
# *Crawler filing_10K: b'0000779544' - b'ARKR'
# *Crawler filing_10K: b'0000013573' - b'BWL.A'
# *Crawler filing_10K: b'0000006885' - b'SSI'
# *Crawler filing_10K: b'0001082923' - b'STMP'
# *Crawler filing_10K: b'0000913955' - b'AZK'
# *Crawler filing_10K: b'0001259648' - b'RAK.1'
# *Crawler filing_10K: b'0000880984' - b'ACFN'
# *Crawler filing_10K: b'0001129425' - b'ZGEN'
# *Crawler filing_10K: b'0000216539' - b'MEG'
# *Crawler filing_10K: b'0001325281' - b'KS'
# *Crawler filing_10K: b'0001320934' - b'ICO'
# *Crawler filing_10K: b'0001044590' - b'IN'
# *Crawler filing_10K: b'0001084048' - b'JCOM'
# *Crawler filing_10K: b'0001158113' - b'FDG.1'
# *Crawler filing_10K: b'0001020710' - b'DXPE'
# *Crawler filing_10K: b'0000842518' - b'EVBN'
# *Crawler filing_10K: b'0001000694' - b'NVAX'
# *Crawler filing_10K: b'0000721683' - b'TSS'
# *Crawler filing_10K: b'0001113256' - b'MTOR'
# *Crawler filing_10K: b'0000352363' - b'KATE'
# *Crawler filing_10K: b'0001398659' - b'G'
# *Crawler filing_10K: b'0001339729' - b'ORCD'
# *Crawler filing_10K: b'0000943452' - b'WAB'
# *Crawler filing_10K: b'0000808362' - b'BHI'
# *Crawler filing_10K: b'0000722617' - b'MDNU'
# *Crawler filing_10K: b'0000884269' - b'APT'
# *Crawler filing_10K: b'0000355766' - b'HWG'
# *Crawler filing_10K: b'0000794323' - b'LVLT'
# *Crawler filing_10K: b'0001270400' - b'VMED'
# *Crawler filing_10K: b'0001385830' - b'NGSX'
# *Crawler filing_10K: b'0001227930' - b'ENTR'
# *Crawler filing_10K: b'0001086745' - b'WPCS'
# *Crawler filing_10K: b'0001057379' - b'HCKT'
# *Crawler filing_10K: b'0001314102' - b'PSDV'
# *Crawler filing_10K: b'0000912890' - b'TMRK'
# *Crawler filing_10K: b'0000935036' - b'ACIW'
# *Crawler filing_10K: b'0000316253' - b'ENZ'
# *Crawler filing_10K: b'0000907410' - b'ESST'
# *Crawler filing_10K: b'0000078814' - b'PBI'
# *Crawler filing_10K: b'0000846546' - b'BNSO'
# *Crawler filing_10K: b'0000768251' - b'ALTR'
# *Crawler filing_10K: b'0000936468' - b'LMT'
# *Crawler filing_10K: b'0001392600' - b'ESMK'
# *Crawler filing_10K: b'0001082423' - b'RUBO'
# *Crawler filing_10K: b'0000799292' - b'MHO'
# *Crawler filing_10K: b'0000915358' - b'SGMA'
# *Crawler filing_10K: b'0001350653' - b'ATEC'
# *Crawler filing_10K: b'0000930420' - b'KFRC'
# *Crawler filing_10K: b'0001335190' - b'MHR'
# *Crawler filing_10K: b'0000887497' - b'HITK'
# *Crawler filing_10K: b'0001042351' - b'IDGR'
# *Crawler filing_10K: b'0000719135' - b'BVX'
# *Crawler filing_10K: b'0001004673' - b'EGT'
# *Crawler filing_10K: b'0001168652' - b'HIRE'
# *Crawler filing_10K: b'0000089270' - b'SLI'
# *Crawler filing_10K: b'0001017440' - b'AUSA'
# *Crawler filing_10K: b'0000788965' - b'HNRG'
# *Crawler filing_10K: b'0001066134' - b'COCOQ'
# *Crawler filing_10K: b'0001168335' - b'EYE'
# *Crawler filing_10K: b'0001090514' - b'AOBI'
# *Crawler filing_10K: b'0000740694' - b'KDN'
# *Crawler filing_10K: b'0001375877' - b'CSIQ'
# *Crawler filing_10K: b'0000929700' - b'PTINY'
# *Crawler filing_10K: b'0001156041' - b'HUSA'
# *Crawler filing_10K: b'0000868780' - b'DORM'
# *Crawler filing_10K: b'0001115143' - b'ACUS'
# *Crawler filing_10K: b'0000100493' - b'TSN'
# *Crawler filing_10K: b'0000072911' - b'NRTLQ'
# *Crawler filing_10K: b'0001006281' - b'PLX'
# *Crawler filing_10K: b'0000818813' - b'BITS'
# *Crawler filing_10K: b'0000899597' - b'BKI'
# *Crawler filing_10K: b'0001038144' - b'ACSEF'
# *Crawler filing_10K: b'0000040987' - b'GPC'
# *Crawler filing_10K: b'0001343202' - b'VSUNQ'
# *Crawler filing_10K: b'0000057528' - b'LNCE'
# *Crawler filing_10K: b'0001292653' - b'IQNT'
# *Crawler filing_10K: b'0000026537' - b'STST.1'
# *Crawler filing_10K: b'0000313143' - b'HAE'
# *Crawler filing_10K: b'0001050797' - b'COLM'
# *Crawler filing_10K: b'0001030206' - b'VASC'
# *Crawler filing_10K: b'0001303936' - b'CDYCD'
# *Crawler filing_10K: b'0001396278' - b'LIMS'
# *Crawler filing_10K: b'0000107140' - b'JW.A'
# *Crawler filing_10K: b'0001341170' - b'ESEA'
# *Crawler filing_10K: b'0000764579' - b'CASM'
# *Crawler filing_10K: b'0000065770' - b'MVIS'
# *Crawler filing_10K: b'0000100591' - b'AGX'
# *Crawler filing_10K: b'0001117106' - b'N'
# *Crawler filing_10K: b'0000922658' - b'ZICA'
# *Crawler filing_10K: b'0000928876' - b'TSEM'
# *Crawler filing_10K: b'0001168696' - b'RGC'
# *Crawler filing_10K: b'0000320187' - b'NKE'
# *Crawler filing_10K: b'0001043509' - b'SAH'
# *Crawler filing_10K: b'0000857073' - b'HQSM'
# *Crawler filing_10K: b'0000892450' - b'KT'
# *Crawler filing_10K: b'0000865752' - b'MNST'
# *Crawler filing_10K: b'0001067294' - b'CBRL'
# *Crawler filing_10K: b'0001076930' - b'GSIG'
# *Crawler filing_10K: b'0001070698' - b'RPTP'
# *Crawler filing_10K: b'0001292055' - b'SMA'
# *Crawler filing_10K: b'0001163698' - b'SDBT'
# *Crawler filing_10K: b'0001411419' - b'CEDU'
# *Crawler filing_10K: b'0000915127' - b'PHC.3'
# *Crawler filing_10K: b'0000016875' - b'CP'
# *Crawler filing_10K: b'0001342338' - b'HIMX'
# *Crawler filing_10K: b'0000868857' - b'ACM'
# *Crawler filing_10K: b'0000906337' - b'PILLQ'
# *Crawler filing_10K: b'0001191255' - b'CHA'
# *Crawler filing_10K: b'0001108906' - b'SRVY'
# *Crawler filing_10K: b'0001042291' - b'ILNC'
# *Crawler filing_10K: b'0001367083' - b'OCLS'
# *Crawler filing_10K: b'0000890634' - b'AHCI'
# *Crawler filing_10K: b'0000356037' - b'CSPI'
# *Crawler filing_10K: b'0001012620' - b'GWR'
# *Crawler filing_10K: b'0000912833' - b'WMAR'
# *Crawler filing_10K: b'0001375247' - b'OMPI'
# *Crawler filing_10K: b'0001121404' - b'SNY'
# *Crawler filing_10K: b'0000815556' - b'FAST'
# *Crawler filing_10K: b'0000880562' - b'DAEG'
# *Crawler filing_10K: b'0000866374' - b'FLEX'
# *Crawler filing_10K: b'0000014707' - b'CAL'
# *Crawler filing_10K: b'0001206264' - b'TPX'
# *Crawler filing_10K: b'0000730272' - b'RGEN'
# *Crawler filing_10K: b'0001016546' - b'ALTI'
# *Crawler filing_10K: b'0000799850' - b'CRMT'
# *Crawler filing_10K: b'0000103379' - b'VFC'
# *Crawler filing_10K: b'0001260990' - b'GTXI'
# *Crawler filing_10K: b'0001377936' - b'SAR'
# *Crawler filing_10K: b'0000277924' - b'CRED.'
# *Crawler filing_10K: b'0000879764' - b'TOT'
# *Crawler filing_10K: b'0001077552' - b'GETI'
# *Crawler filing_10K: b'0000859737' - b'HOLX'
# *Crawler filing_10K: b'0000908598' - b'ATRM'
# *Crawler filing_10K: b'0001040896' - b'IDN'
# *Crawler filing_10K: b'0000906193' - b'KTEC'
# *Crawler filing_10K: b'0001396546' - b'VM'
# *Crawler filing_10K: b'0001243429' - b'MT'
# *Crawler filing_10K: b'0000946563' - b'RVP'
# *Crawler filing_10K: b'0001004724' - b'ADK'
# *Crawler filing_10K: b'0001401678' - b'VOLT.'
# *Crawler filing_10K: b'0000351834' - b'STKL'
# *Crawler filing_10K: b'0001053507' - b'AMT'
# *Crawler filing_10K: b'0000916076' - b'MLM'
# *Crawler filing_10K: b'0001048477' - b'BMRN'
# *Crawler filing_10K: b'0001037016' - b'NIHD'
# *Crawler filing_10K: b'0001172480' - b'SNTS'
# *Crawler filing_10K: b'0000872448' - b'ATML'
# *Crawler filing_10K: b'0000946842' - b'AMIEQ'
# *Crawler filing_10K: b'0000894253' - b'PER.1'
# *Crawler filing_10K: b'0000315449' - b'UQM'
# *Crawler filing_10K: b'0001369377' - b'QMNDQ'
# *Crawler filing_10K: b'0001364714' - b'OKN'
# *Crawler filing_10K: b'0000057055' - b'KVPHQ'
# *Crawler filing_10K: b'0001324410' - b'GBNK'
# *Crawler filing_10K: b'0001072483' - b'SPPJY'
# *Crawler filing_10K: b'0001087432' - b'ITMN'
# *Crawler filing_10K: b'0001083132' - b'IMMCQ'
# *Crawler filing_10K: b'0000058492' - b'LEG'
# *Crawler filing_10K: b'0001091756' - b'IBAS'
# *Crawler filing_10K: b'0000701719' - b'DGSE'
# *Crawler filing_10K: b'0001106714' - b'PSITY'
# *Crawler filing_10K: b'0001317362' - b'SHMR'
# *Crawler filing_10K: b'0001130713' - b'OSTK'
# *Crawler filing_10K: b'0001041829' - b'AUSPF'
# *Crawler filing_10K: b'0001413257' - b'GRO'
# *Crawler filing_10K: b'0000850579' - b'PLXT'
# *Crawler filing_10K: b'0001065088' - b'EBAY'
# *Crawler filing_10K: b'0001082038' - b'DRRX'
# *Crawler filing_10K: b'0001383312' - b'BR'
# *Crawler filing_10K: b'0000100726' - b'UFI'
# *Crawler filing_10K: b'0000048465' - b'HRL'
# *Crawler filing_10K: b'0001201792' - b'APEI'
# *Crawler filing_10K: b'0000313478' - b'HKNI'
# *Crawler filing_10K: b'0000912151' - b'CFK'
# *Crawler filing_10K: b'0000051644' - b'IPG'
# *Crawler filing_10K: b'0000840883' - b'BTUI'
# *Crawler filing_10K: b'0000024545' - b'TAP'
# *Crawler filing_10K: b'0000048287' - b'HNI'
# *Crawler filing_10K: b'0001116927' - b'GEOR'
# *Crawler filing_10K: b'0000805022' - b'BPL'
# *Crawler filing_10K: b'0000095574' - b'SGC'
# *Crawler filing_10K: b'0000059440' - b'VGR'
# *Crawler filing_10K: b'0000203527' - b'VAR'
# *Crawler filing_10K: b'0001049606' - b'CIX'
# *Crawler filing_10K: b'0000706688' - b'AAN'
# *Crawler filing_10K: b'0001040829' - b'RHP'
# *Crawler filing_10K: b'0000052827' - b'RYN'
# *Crawler filing_10K: b'0001314772' - b'SUMR'
# *Crawler filing_10K: b'0000909326' - b'ASYTQ'
# *Crawler filing_10K: b'0001274057' - b'HSP'
# *Crawler filing_10K: b'0001085621' - b'ACTA'
# *Crawler filing_10K: b'0000915909' - b'HRSH'
# *Crawler filing_10K: b'0000820313' - b'APH'
# *Crawler filing_10K: b'0000885306' - b'CYNO'
# *Crawler filing_10K: b'0000919956' - b'DVCR'
# *Crawler filing_10K: b'0001405419' - b'GIGIQ'
# *Crawler filing_10K: b'0000882835' - b'ROP'
# *Crawler filing_10K: b'0000794619' - b'AMWD'
# *Crawler filing_10K: b'0000896494' - b'MAGS'
# *Crawler filing_10K: b'0001158172' - b'SCOR'
# *Crawler filing_10K: b'0000913165' - b'EXAC'
# *Crawler filing_10K: b'0001332341' - b'USBE'
# *Crawler filing_10K: b'0001272830' - b'VG'
# *Crawler filing_10K: b'0000789073' - b'BEAM'
# *Crawler filing_10K: b'0001347510' - b'GRRF'
# *Crawler filing_10K: b'0000789019' - b'MSFT'
# *Crawler filing_10K: b'0000714603' - b'DST'
# *Crawler filing_10K: b'0001345105' - b'CPA'
# *Crawler filing_10K: b'0000739944' - b'MTOX'
# *Crawler filing_10K: b'0000086144' - b'SWY'
# *Crawler filing_10K: b'0001138817' - b'FSGI'
# *Crawler filing_10K: b'0001301063' - b'ANRZQ'
# *Crawler filing_10K: b'0000009779' - b'FCHDQ'
# *Crawler filing_10K: b'0000912958' - b'MIICF'
# *Crawler filing_10K: b'0001088166' - b'PGH'
# *Crawler filing_10K: b'0001450598' - b'INVHY'
# *Crawler filing_10K: b'0000096021' - b'SYY'
# *Crawler filing_10K: b'0001124610' - b'VMW'
# *Crawler filing_10K: b'0001009759' - b'CPST'
# *Crawler filing_10K: b'0001422862' - b'PMFG'
# *Crawler filing_10K: b'0001030749' - b'GLF'

# %%
#wp.data.set_index(keys=['date'], inplace=True)
#wp.data = wp.data.loc[(wp.data.index >= '01-01-' + str(start)) & (wp.data.index <= '12-31-' + str(end))]
#wp.data.sort_index(inplace=True)
#wp.data.reset_index(inplace=True)
#wp.data.drop('index', axis=1, inplace=True)
wp.data
#rds.set('data:crsp-comp:2008-2008', zlib.compress(pickle.dumps(wp.data)))
# Out:
# True

# %%
reload(WordPower)

# %%
dir(wp)

# %%
#del wp, WordPower

# %%
whos WordPower
